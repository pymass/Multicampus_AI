# %%
# Basic Syntax
print("Hello, Python")

#!/usr/bin/python3
# python test.py

#t = t + \
#    t + 1
test = ['test','test1']
test2 = 'test'
test3 = "test"
test4 = "test" #test comment
'''
Mulitple Comment
'''
input("\n\nTest Input")
import sys; x = 'test';print(x)

# %%
# Variable Types
counter = 100
miles = 1000.0
name = "Tom"
print(counter)
print(miles)
print(name)
a = b = c = 1
#a, b, c=1, 2, "john"

# - Standard Data Types
# Numbers
# String
# List
# Tuple
# Dictionary

# Numbers
var1 = 1
var2 = 20
var3 = 30

del var1
del var2, var3
# Numerical types -> int, float, complex 
# int -> 10
# float -> 0.0
# comple -> 3.14j

# String

str = "Hello Python"
print(str)
print(str[0]) # First charactor of the string
print(str[2:3])

#  H e l l o
# 0 1 2 3 4 5
print(str[2:])
print(str * 2)
print(str + "Test")
str[:-1]
#  H e l  l  o
#  -2  -1  

# List
list = ['abcd', 'a', 10, 23.1, 'Tome']
print(list)
print(list[0])
print(list[1:3])
print(list[2:])
print(list * 2)
list2 = ["apple", "orange"]
print(list + list2)


# Tuple
tuple = (1,"2", "test")
print(tuple)
#uple[0] = 100
print(tuple[0])
print(tuple[1:3])
print(tuple[2:])

# Dictionary
dict = {}
print(dict)
dict['one'] = "This is one"
print(dict)
dict['two'] = "This is two"
print(dict)
print(dict.keys())
print(dict.values())
var12 = 20
chr(var12)
# Data Conversion
# set, dict, str, int, float, repr, eval, tuple...
# Out:
# 100
# 1000.0
# Tom
# Hello Python
# H
# l
# llo Python
# Hello PythonHello Python
# Hello PythonTest
# ['abcd', 'a', 10, 23.1, 'Tome']
# abcd
# ['a', 10]
# [10, 23.1, 'Tome']
# ['abcd', 'a', 10, 23.1, 'Tome', 'abcd', 'a', 10, 23.1, 'Tome']
# ['abcd', 'a', 10, 23.1, 'Tome', 'apple', 'orange']
# (1, '2', 'test')
# 1
# ('2', 'test')
# ('test',)
# {}
# {'one': 'This is one'}
# {'one': 'This is one', 'two': 'This is two'}
# dict_keys(['one', 'two'])
# dict_values(['This is one', 'This is two'])
# '\x14'

# %%
# Basic Operators
# Arithmetic Operator
# +, -, *, /, %, **
# Comparision Operator
# ==, !=, >,<, >=,<=
# Assigment Operator
# =, +=, -=, *=, **=
# Logical Operator
# and, or, not
# Bitwise Operator
# Membership Operator
# in, not in
# Identity Operator

# %%
# Decision Making
var10 = 1
if var10:
    print("1")
    print(var10)


var10 = 10
if var10:
    print("1")
else:
    print("not 1")
    
discount = 0
amount = int(input("Enter amount: "))
if amount < 1000:
    discount = amount * 0.05
    print("Discount", discount)
else:
    discount = amount * 0.10
    print("Discount", discount)

discount = 0
amount2 = int(input("Enter amount2: "))    
if amount2 < 1000:
    discount = amount2 * 0.05
    print("Discount", discount)
elif amount2 < 5000:
    discount = amount2 * 0.10
    print("Discount", discount)
else amount2 < 100:
    print("Amount2 : ", amount2)
# Out:
# 1
# 1
# 1
# Enter amount: 1000
# Discount 0.0

# %%
# Loops
count = 0
while(count < 9):
    print("Count", count)
    count = count + 1
print("End")    

var = 1
while var == 1:
    num = int(input("Enter a number :"))
    print("You entered: ", num)
    
print("End")
# Out:
# Count 0
# Count 1
# Count 2
# Count 3
# Count 4
# Count 5
# Count 6
# Count 7
# Count 8
# End

# %%
count = 0
while count < 5:
    print(count, " is less then 5")
    count = count + 1
else:
    print(count, " is not less then 5")

flag = 1
while(flag): print("Test While")
print("End")
# Out:
# 0  is less then 5
# 1  is less then 5
# 2  is less then 5
# 3  is less then 5
# 4  is less then 5
# 5  is not less then 5
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# Test While
# ...

# %%
#!/usr/bin/env python

# %%
# File I/O

# %%
# Exceptions

# %%
# Classs/Objects
