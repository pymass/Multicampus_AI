# %%
from keras.models import Sequential, load_model
from keras.layers.core import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy as np
import os
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
df_pre = pd.read_csv('wine.csv', header=None)
df = df_pre.sample(frac=0.15)

# %%
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\ai\Anaconda3\envs\mlpy36\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# %%
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

# %%
modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

# %%
model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, \
          callbacks=[early_stopping_callback,checkpointer])
# Out:
# WARNING:tensorflow:From C:\Users\ai\Anaconda3\envs\mlpy36\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# Epoch 00001: val_loss improved from inf to 0.48570, saving model to ./model/01-0.4857.hdf5
#
# Epoch 00002: val_loss improved from 0.48570 to 0.45984, saving model to ./model/02-0.4598.hdf5
#
# Epoch 00003: val_loss improved from 0.45984 to 0.43402, saving model to ./model/03-0.4340.hdf5
#
# Epoch 00004: val_loss improved from 0.43402 to 0.42041, saving model to ./model/04-0.4204.hdf5
#
# Epoch 00005: val_loss improved from 0.42041 to 0.40760, saving model to ./model/05-0.4076.hdf5
#
# Epoch 00006: val_loss improved from 0.40760 to 0.39435, saving model to ./model/06-0.3943.hdf5
#
# Epoch 00007: val_loss improved from 0.39435 to 0.38627, saving model to ./model/07-0.3863.hdf5
#
# Epoch 00008: val_loss improved from 0.38627 to 0.37928, saving model to ./model/08-0.3793.hdf5
#
# Epoch 00009: val_loss improved from 0.37928 to 0.37256, saving model to ./model/09-0.3726.hdf5
#
# Epoch 00010: val_loss improved from 0.37256 to 0.36564, saving model to ./model/10-0.3656.hdf5
#
# Epoch 00011: val_loss improved from 0.36564 to 0.35949, saving model to ./model/11-0.3595.hdf5
#
# Epoch 00012: val_loss improved from 0.35949 to 0.35429, saving model to ./model/12-0.3543.hdf5
#
# Epoch 00013: val_loss improved from 0.35429 to 0.34957, saving model to ./model/13-0.3496.hdf5
#
# Epoch 00014: val_loss improved from 0.34957 to 0.34480, saving model to ./model/14-0.3448.hdf5
#
# Epoch 00015: val_loss improved from 0.34480 to 0.33885, saving model to ./model/15-0.3389.hdf5
#
# Epoch 00016: val_loss improved from 0.33885 to 0.33345, saving model to ./model/16-0.3334.hdf5
#
# Epoch 00017: val_loss improved from 0.33345 to 0.32874, saving model to ./model/17-0.3287.hdf5
#
# Epoch 00018: val_loss improved from 0.32874 to 0.32493, saving model to ./model/18-0.3249.hdf5
#
# Epoch 00019: val_loss improved from 0.32493 to 0.32343, saving model to ./model/19-0.3234.hdf5
#
# Epoch 00020: val_loss improved from 0.32343 to 0.31960, saving model to ./model/20-0.3196.hdf5
#
# Epoch 00021: val_loss improved from 0.31960 to 0.31240, saving model to ./model/21-0.3124.hdf5
#
# Epoch 00022: val_loss improved from 0.31240 to 0.30769, saving model to ./model/22-0.3077.hdf5
#
# Epoch 00023: val_loss improved from 0.30769 to 0.30352, saving model to ./model/23-0.3035.hdf5
#
# Epoch 00024: val_loss improved from 0.30352 to 0.30035, saving model to ./model/24-0.3003.hdf5
#
# Epoch 00025: val_loss improved from 0.30035 to 0.29827, saving model to ./model/25-0.2983.hdf5
#
# Epoch 00026: val_loss improved from 0.29827 to 0.29348, saving model to ./model/26-0.2935.hdf5
#
# Epoch 00027: val_loss improved from 0.29348 to 0.28767, saving model to ./model/27-0.2877.hdf5
#
# Epoch 00028: val_loss improved from 0.28767 to 0.28374, saving model to ./model/28-0.2837.hdf5
#
# Epoch 00029: val_loss improved from 0.28374 to 0.27918, saving model to ./model/29-0.2792.hdf5
#
# Epoch 00030: val_loss improved from 0.27918 to 0.27655, saving model to ./model/30-0.2765.hdf5
#
# Epoch 00031: val_loss improved from 0.27655 to 0.27245, saving model to ./model/31-0.2724.hdf5
#
# Epoch 00032: val_loss improved from 0.27245 to 0.26759, saving model to ./model/32-0.2676.hdf5
#
# Epoch 00033: val_loss improved from 0.26759 to 0.26391, saving model to ./model/33-0.2639.hdf5
#
# Epoch 00034: val_loss improved from 0.26391 to 0.26051, saving model to ./model/34-0.2605.hdf5
#
# Epoch 00035: val_loss improved from 0.26051 to 0.25881, saving model to ./model/35-0.2588.hdf5
#
# Epoch 00036: val_loss improved from 0.25881 to 0.25560, saving model to ./model/36-0.2556.hdf5
#
# Epoch 00037: val_loss improved from 0.25560 to 0.25233, saving model to ./model/37-0.2523.hdf5
#
# Epoch 00038: val_loss improved from 0.25233 to 0.24975, saving model to ./model/38-0.2498.hdf5
#
# Epoch 00039: val_loss improved from 0.24975 to 0.24758, saving model to ./model/39-0.2476.hdf5
#
# Epoch 00040: val_loss improved from 0.24758 to 0.24564, saving model to ./model/40-0.2456.hdf5
#
# Epoch 00041: val_loss improved from 0.24564 to 0.24464, saving model to ./model/41-0.2446.hdf5
#
# Epoch 00042: val_loss improved from 0.24464 to 0.24245, saving model to ./model/42-0.2424.hdf5
#
# Epoch 00043: val_loss improved from 0.24245 to 0.24060, saving model to ./model/43-0.2406.hdf5
#
# Epoch 00044: val_loss improved from 0.24060 to 0.23861, saving model to ./model/44-0.2386.hdf5
#
# Epoch 00045: val_loss improved from 0.23861 to 0.23789, saving model to ./model/45-0.2379.hdf5
#
# Epoch 00046: val_loss improved from 0.23789 to 0.23774, saving model to ./model/46-0.2377.hdf5
#
# Epoch 00047: val_loss improved from 0.23774 to 0.23518, saving model to ./model/47-0.2352.hdf5
#
# Epoch 00048: val_loss improved from 0.23518 to 0.23242, saving model to ./model/48-0.2324.hdf5
#
# Epoch 00049: val_loss improved from 0.23242 to 0.23077, saving model to ./model/49-0.2308.hdf5
#
# Epoch 00050: val_loss improved from 0.23077 to 0.22996, saving model to ./model/50-0.2300.hdf5
#
# Epoch 00051: val_loss improved from 0.22996 to 0.22812, saving model to ./model/51-0.2281.hdf5
#
# Epoch 00052: val_loss improved from 0.22812 to 0.22684, saving model to ./model/52-0.2268.hdf5
#
# Epoch 00053: val_loss improved from 0.22684 to 0.22534, saving model to ./model/53-0.2253.hdf5
#
# Epoch 00054: val_loss improved from 0.22534 to 0.22451, saving model to ./model/54-0.2245.hdf5
#
# Epoch 00055: val_loss improved from 0.22451 to 0.22334, saving model to ./model/55-0.2233.hdf5
#
# Epoch 00056: val_loss improved from 0.22334 to 0.22144, saving model to ./model/56-0.2214.hdf5
#
# Epoch 00057: val_loss improved from 0.22144 to 0.21989, saving model to ./model/57-0.2199.hdf5
#
# Epoch 00058: val_loss improved from 0.21989 to 0.21835, saving model to ./model/58-0.2183.hdf5
#
# Epoch 00059: val_loss improved from 0.21835 to 0.21684, saving model to ./model/59-0.2168.hdf5
#
# Epoch 00060: val_loss improved from 0.21684 to 0.21654, saving model to ./model/60-0.2165.hdf5
#
# Epoch 00061: val_loss did not improve from 0.21654
#
# Epoch 00062: val_loss improved from 0.21654 to 0.21340, saving model to ./model/62-0.2134.hdf5
#
# Epoch 00063: val_loss improved from 0.21340 to 0.21094, saving model to ./model/63-0.2109.hdf5
#
# Epoch 00064: val_loss improved from 0.21094 to 0.20944, saving model to ./model/64-0.2094.hdf5
#
# Epoch 00065: val_loss improved from 0.20944 to 0.20932, saving model to ./model/65-0.2093.hdf5
#
# Epoch 00066: val_loss improved from 0.20932 to 0.20852, saving model to ./model/66-0.2085.hdf5
#
# Epoch 00067: val_loss improved from 0.20852 to 0.20583, saving model to ./model/67-0.2058.hdf5
#
# Epoch 00068: val_loss improved from 0.20583 to 0.20500, saving model to ./model/68-0.2050.hdf5
#
# Epoch 00069: val_loss improved from 0.20500 to 0.20367, saving model to ./model/69-0.2037.hdf5
#
# Epoch 00070: val_loss improved from 0.20367 to 0.20364, saving model to ./model/70-0.2036.hdf5
#
# Epoch 00071: val_loss did not improve from 0.20364
#
# Epoch 00072: val_loss improved from 0.20364 to 0.20209, saving model to ./model/72-0.2021.hdf5
#
# Epoch 00073: val_loss improved from 0.20209 to 0.19929, saving model to ./model/73-0.1993.hdf5
#
# Epoch 00074: val_loss improved from 0.19929 to 0.19816, saving model to ./model/74-0.1982.hdf5
#
# Epoch 00075: val_loss improved from 0.19816 to 0.19800, saving model to ./model/75-0.1980.hdf5
#
# Epoch 00076: val_loss did not improve from 0.19800
#
# Epoch 00077: val_loss improved from 0.19800 to 0.19742, saving model to ./model/77-0.1974.hdf5
#
# Epoch 00078: val_loss improved from 0.19742 to 0.19569, saving model to ./model/78-0.1957.hdf5
#
# Epoch 00079: val_loss improved from 0.19569 to 0.19290, saving model to ./model/79-0.1929.hdf5
#
# Epoch 00080: val_loss improved from 0.19290 to 0.19155, saving model to ./model/80-0.1916.hdf5
#
# Epoch 00081: val_loss did not improve from 0.19155
#
# Epoch 00082: val_loss did not improve from 0.19155
#
# Epoch 00083: val_loss improved from 0.19155 to 0.19140, saving model to ./model/83-0.1914.hdf5
#
# Epoch 00084: val_loss improved from 0.19140 to 0.18844, saving model to ./model/84-0.1884.hdf5
#
# Epoch 00085: val_loss improved from 0.18844 to 0.18757, saving model to ./model/85-0.1876.hdf5
#
# Epoch 00086: val_loss improved from 0.18757 to 0.18734, saving model to ./model/86-0.1873.hdf5
#
# Epoch 00087: val_loss did not improve from 0.18734
#
# Epoch 00088: val_loss did not improve from 0.18734
#
# Epoch 00089: val_loss improved from 0.18734 to 0.18661, saving model to ./model/89-0.1866.hdf5
#
# Epoch 00090: val_loss improved from 0.18661 to 0.18400, saving model to ./model/90-0.1840.hdf5
#
# Epoch 00091: val_loss improved from 0.18400 to 0.18273, saving model to ./model/91-0.1827.hdf5
#
# Epoch 00092: val_loss did not improve from 0.18273
#
# Epoch 00093: val_loss did not improve from 0.18273
#
# Epoch 00094: val_loss did not improve from 0.18273
# Epoch 00095: val_loss improved from 0.18273 to 0.18180, saving model to ./model/95-0.1818.hdf5
#
# Epoch 00096: val_loss improved from 0.18180 to 0.18089, saving model to ./model/96-0.1809.hdf5
#
# Epoch 00097: val_loss improved from 0.18089 to 0.18045, saving model to ./model/97-0.1804.hdf5
#
# Epoch 00098: val_loss improved from 0.18045 to 0.17950, saving model to ./model/98-0.1795.hdf5
#
# Epoch 00099: val_loss improved from 0.17950 to 0.17922, saving model to ./model/99-0.1792.hdf5
#
# Epoch 00100: val_loss improved from 0.17922 to 0.17770, saving model to ./model/100-0.1777.hdf5
#
# Epoch 00101: val_loss improved from 0.17770 to 0.17635, saving model to ./model/101-0.1764.hdf5
#
# Epoch 00102: val_loss improved from 0.17635 to 0.17451, saving model to ./model/102-0.1745.hdf5
#
# Epoch 00103: val_loss improved from 0.17451 to 0.17382, saving model to ./model/103-0.1738.hdf5
#
# Epoch 00104: val_loss did not improve from 0.17382
#
# Epoch 00105: val_loss did not improve from 0.17382
#
# Epoch 00106: val_loss did not improve from 0.17382
#
# Epoch 00107: val_loss improved from 0.17382 to 0.17029, saving model to ./model/107-0.1703.hdf5
#
# Epoch 00108: val_loss improved from 0.17029 to 0.16953, saving model to ./model/108-0.1695.hdf5
#
# Epoch 00109: val_loss did not improve from 0.16953
#
# Epoch 00110: val_loss did not improve from 0.16953
#
# Epoch 00111: val_loss did not improve from 0.16953
#
# Epoch 00112: val_loss improved from 0.16953 to 0.16693, saving model to ./model/112-0.1669.hdf5
#
# Epoch 00113: val_loss improved from 0.16693 to 0.16633, saving model to ./model/113-0.1663.hdf5
#
# Epoch 00114: val_loss did not improve from 0.16633
#
# Epoch 00115: val_loss did not improve from 0.16633
#
# Epoch 00116: val_loss did not improve from 0.16633
#
# Epoch 00117: val_loss improved from 0.16633 to 0.16490, saving model to ./model/117-0.1649.hdf5
#
# Epoch 00118: val_loss improved from 0.16490 to 0.16444, saving model to ./model/118-0.1644.hdf5
#
# Epoch 00119: val_loss did not improve from 0.16444
#
# Epoch 00120: val_loss did not improve from 0.16444
#
# Epoch 00121: val_loss improved from 0.16444 to 0.16416, saving model to ./model/121-0.1642.hdf5
#
# Epoch 00122: val_loss improved from 0.16416 to 0.16048, saving model to ./model/122-0.1605.hdf5
#
# Epoch 00123: val_loss did not improve from 0.16048
#
# Epoch 00124: val_loss did not improve from 0.16048
#
# Epoch 00125: val_loss did not improve from 0.16048
#
# Epoch 00126: val_loss did not improve from 0.16048
#
# Epoch 00127: val_loss improved from 0.16048 to 0.15824, saving model to ./model/127-0.1582.hdf5
#
# Epoch 00128: val_loss did not improve from 0.15824
#
# Epoch 00129: val_loss did not improve from 0.15824
#
# Epoch 00130: val_loss did not improve from 0.15824
#
# Epoch 00131: val_loss did not improve from 0.15824
#
# Epoch 00132: val_loss improved from 0.15824 to 0.15618, saving model to ./model/132-0.1562.hdf5
#
# Epoch 00133: val_loss improved from 0.15618 to 0.15539, saving model to ./model/133-0.1554.hdf5
#
# Epoch 00134: val_loss did not improve from 0.15539
#
# Epoch 00135: val_loss did not improve from 0.15539
#
# Epoch 00136: val_loss improved from 0.15539 to 0.15468, saving model to ./model/136-0.1547.hdf5
#
# Epoch 00137: val_loss improved from 0.15468 to 0.15346, saving model to ./model/137-0.1535.hdf5
#
# Epoch 00138: val_loss did not improve from 0.15346
#
# Epoch 00139: val_loss did not improve from 0.15346
#
# Epoch 00140: val_loss improved from 0.15346 to 0.15240, saving model to ./model/140-0.1524.hdf5
#
# Epoch 00141: val_loss improved from 0.15240 to 0.15125, saving model to ./model/141-0.1512.hdf5
#
# Epoch 00142: val_loss did not improve from 0.15125
#
# Epoch 00143: val_loss did not improve from 0.15125
#
# Epoch 00144: val_loss did not improve from 0.15125
#
# Epoch 00145: val_loss improved from 0.15125 to 0.14930, saving model to ./model/145-0.1493.hdf5
#
# Epoch 00146: val_loss improved from 0.14930 to 0.14880, saving model to ./model/146-0.1488.hdf5
#
# Epoch 00147: val_loss did not improve from 0.14880
#
# Epoch 00148: val_loss did not improve from 0.14880
#
# Epoch 00149: val_loss did not improve from 0.14880
#
# Epoch 00150: val_loss did not improve from 0.14880
#
# Epoch 00151: val_loss did not improve from 0.14880
#
# Epoch 00152: val_loss did not improve from 0.14880
#
# Epoch 00153: val_loss did not improve from 0.14880
#
# Epoch 00154: val_loss improved from 0.14880 to 0.14610, saving model to ./model/154-0.1461.hdf5
#
# Epoch 00155: val_loss improved from 0.14610 to 0.14421, saving model to ./model/155-0.1442.hdf5
#
# Epoch 00156: val_loss did not improve from 0.14421
#
# Epoch 00157: val_loss did not improve from 0.14421
#
# Epoch 00158: val_loss did not improve from 0.14421
#
# Epoch 00159: val_loss did not improve from 0.14421
#
# Epoch 00160: val_loss improved from 0.14421 to 0.14334, saving model to ./model/160-0.1433.hdf5
#
# Epoch 00161: val_loss did not improve from 0.14334
#
# Epoch 00162: val_loss did not improve from 0.14334
#
# Epoch 00163: val_loss improved from 0.14334 to 0.14289, saving model to ./model/163-0.1429.hdf5
#
# Epoch 00164: val_loss improved from 0.14289 to 0.14073, saving model to ./model/164-0.1407.hdf5
#
# Epoch 00165: val_loss did not improve from 0.14073
#
# Epoch 00166: val_loss did not improve from 0.14073
#
# Epoch 00167: val_loss did not improve from 0.14073
#
# Epoch 00168: val_loss improved from 0.14073 to 0.13945, saving model to ./model/168-0.1395.hdf5
#
# Epoch 00169: val_loss improved from 0.13945 to 0.13839, saving model to ./model/169-0.1384.hdf5
#
# Epoch 00170: val_loss did not improve from 0.13839
#
# Epoch 00171: val_loss did not improve from 0.13839
#
# Epoch 00172: val_loss did not improve from 0.13839
#
# Epoch 00173: val_loss did not improve from 0.13839
#
# Epoch 00174: val_loss did not improve from 0.13839
#
# Epoch 00175: val_loss did not improve from 0.13839
#
# Epoch 00176: val_loss improved from 0.13839 to 0.13565, saving model to ./model/176-0.1356.hdf5
#
# Epoch 00177: val_loss did not improve from 0.13565
#
# Epoch 00178: val_loss did not improve from 0.13565
#
# Epoch 00179: val_loss did not improve from 0.13565
#
# Epoch 00180: val_loss did not improve from 0.13565
#
# Epoch 00181: val_loss improved from 0.13565 to 0.13355, saving model to ./model/181-0.1335.hdf5
#
# Epoch 00182: val_loss did not improve from 0.13355
#
# Epoch 00183: val_loss did not improve from 0.13355
#
# Epoch 00184: val_loss did not improve from 0.13355
#
# Epoch 00185: val_loss did not improve from 0.13355
#
# Epoch 00186: val_loss improved from 0.13355 to 0.13259, saving model to ./model/186-0.1326.hdf5
#
# Epoch 00187: val_loss did not improve from 0.13259
#
# Epoch 00188: val_loss did not improve from 0.13259
#
# Epoch 00189: val_loss did not improve from 0.13259
#
# Epoch 00190: val_loss improved from 0.13259 to 0.13044, saving model to ./model/190-0.1304.hdf5
#
# Epoch 00191: val_loss did not improve from 0.13044
#
# Epoch 00192: val_loss did not improve from 0.13044
#
# Epoch 00193: val_loss did not improve from 0.13044
#
# Epoch 00194: val_loss improved from 0.13044 to 0.13023, saving model to ./model/194-0.1302.hdf5
#
# Epoch 00195: val_loss did not improve from 0.13023
#
# Epoch 00196: val_loss did not improve from 0.13023
#
# Epoch 00197: val_loss improved from 0.13023 to 0.12980, saving model to ./model/197-0.1298.hdf5
#
# Epoch 00198: val_loss improved from 0.12980 to 0.12745, saving model to ./model/198-0.1274.hdf5
#
# Epoch 00199: val_loss did not improve from 0.12745
#
# Epoch 00200: val_loss did not improve from 0.12745
#
# Epoch 00201: val_loss did not improve from 0.12745
#
# Epoch 00202: val_loss improved from 0.12745 to 0.12645, saving model to ./model/202-0.1264.hdf5
#
# Epoch 00203: val_loss did not improve from 0.12645
#
# Epoch 00204: val_loss did not improve from 0.12645
#
# Epoch 00205: val_loss did not improve from 0.12645
#
# Epoch 00206: val_loss improved from 0.12645 to 0.12588, saving model to ./model/206-0.1259.hdf5
#
# Epoch 00207: val_loss did not improve from 0.12588
#
# Epoch 00208: val_loss did not improve from 0.12588
#
# Epoch 00209: val_loss did not improve from 0.12588
#
# Epoch 00210: val_loss did not improve from 0.12588
#
# Epoch 00211: val_loss improved from 0.12588 to 0.12502, saving model to ./model/211-0.1250.hdf5
#
# Epoch 00212: val_loss did not improve from 0.12502
#
# Epoch 00213: val_loss did not improve from 0.12502
#
# Epoch 00214: val_loss did not improve from 0.12502
#
# Epoch 00215: val_loss improved from 0.12502 to 0.12369, saving model to ./model/215-0.1237.hdf5
#
# Epoch 00216: val_loss did not improve from 0.12369
# Epoch 00217: val_loss did not improve from 0.12369
#
# Epoch 00218: val_loss did not improve from 0.12369
#
# Epoch 00219: val_loss did not improve from 0.12369
#
# Epoch 00220: val_loss did not improve from 0.12369
#
# Epoch 00221: val_loss did not improve from 0.12369
#
# Epoch 00222: val_loss did not improve from 0.12369
#
# Epoch 00223: val_loss did not improve from 0.12369
#
# Epoch 00224: val_loss did not improve from 0.12369
#
# Epoch 00225: val_loss did not improve from 0.12369
#
# Epoch 00226: val_loss did not improve from 0.12369
#
# Epoch 00227: val_loss improved from 0.12369 to 0.12213, saving model to ./model/227-0.1221.hdf5
#
# Epoch 00228: val_loss did not improve from 0.12213
#
# Epoch 00229: val_loss did not improve from 0.12213
#
# Epoch 00230: val_loss improved from 0.12213 to 0.12080, saving model to ./model/230-0.1208.hdf5
#
# Epoch 00231: val_loss improved from 0.12080 to 0.11950, saving model to ./model/231-0.1195.hdf5
#
# Epoch 00232: val_loss did not improve from 0.11950
#
# Epoch 00233: val_loss did not improve from 0.11950
#
# Epoch 00234: val_loss improved from 0.11950 to 0.11855, saving model to ./model/234-0.1185.hdf5
#
# Epoch 00235: val_loss did not improve from 0.11855
#
# Epoch 00236: val_loss did not improve from 0.11855
#
# Epoch 00237: val_loss did not improve from 0.11855
#
# Epoch 00238: val_loss improved from 0.11855 to 0.11796, saving model to ./model/238-0.1180.hdf5
#
# Epoch 00239: val_loss did not improve from 0.11796
#
# Epoch 00240: val_loss did not improve from 0.11796
#
# Epoch 00241: val_loss did not improve from 0.11796
#
# Epoch 00242: val_loss improved from 0.11796 to 0.11592, saving model to ./model/242-0.1159.hdf5
#
# Epoch 00243: val_loss did not improve from 0.11592
#
# Epoch 00244: val_loss did not improve from 0.11592
#
# Epoch 00245: val_loss did not improve from 0.11592
#
# Epoch 00246: val_loss did not improve from 0.11592
#
# Epoch 00247: val_loss did not improve from 0.11592
#
# Epoch 00248: val_loss did not improve from 0.11592
#
# Epoch 00249: val_loss improved from 0.11592 to 0.11574, saving model to ./model/249-0.1157.hdf5
#
# Epoch 00250: val_loss improved from 0.11574 to 0.11351, saving model to ./model/250-0.1135.hdf5
#
# Epoch 00251: val_loss did not improve from 0.11351
#
# Epoch 00252: val_loss did not improve from 0.11351
#
# Epoch 00253: val_loss did not improve from 0.11351
#
# Epoch 00254: val_loss did not improve from 0.11351
#
# Epoch 00255: val_loss did not improve from 0.11351
#
# Epoch 00256: val_loss did not improve from 0.11351
#
# Epoch 00257: val_loss did not improve from 0.11351
#
# Epoch 00258: val_loss improved from 0.11351 to 0.11292, saving model to ./model/258-0.1129.hdf5
#
# Epoch 00259: val_loss did not improve from 0.11292
#
# Epoch 00260: val_loss did not improve from 0.11292
#
# Epoch 00261: val_loss improved from 0.11292 to 0.11269, saving model to ./model/261-0.1127.hdf5
#
# Epoch 00262: val_loss improved from 0.11269 to 0.11159, saving model to ./model/262-0.1116.hdf5
#
# Epoch 00263: val_loss did not improve from 0.11159
#
# Epoch 00264: val_loss did not improve from 0.11159
#
# Epoch 00265: val_loss did not improve from 0.11159
#
# Epoch 00266: val_loss improved from 0.11159 to 0.10878, saving model to ./model/266-0.1088.hdf5
#
# Epoch 00267: val_loss did not improve from 0.10878
#
# Epoch 00268: val_loss did not improve from 0.10878
#
# Epoch 00269: val_loss did not improve from 0.10878
#
# Epoch 00270: val_loss did not improve from 0.10878
#
# Epoch 00271: val_loss did not improve from 0.10878
#
# Epoch 00272: val_loss did not improve from 0.10878
#
# Epoch 00273: val_loss did not improve from 0.10878
#
# Epoch 00274: val_loss did not improve from 0.10878
#
# Epoch 00275: val_loss did not improve from 0.10878
#
# Epoch 00276: val_loss did not improve from 0.10878
#
# Epoch 00277: val_loss did not improve from 0.10878
#
# Epoch 00278: val_loss did not improve from 0.10878
#
# Epoch 00279: val_loss improved from 0.10878 to 0.10807, saving model to ./model/279-0.1081.hdf5
#
# Epoch 00280: val_loss did not improve from 0.10807
#
# Epoch 00281: val_loss did not improve from 0.10807
#
# Epoch 00282: val_loss did not improve from 0.10807
#
# Epoch 00283: val_loss did not improve from 0.10807
#
# Epoch 00284: val_loss did not improve from 0.10807
#
# Epoch 00285: val_loss did not improve from 0.10807
#
# Epoch 00286: val_loss did not improve from 0.10807
#
# Epoch 00287: val_loss improved from 0.10807 to 0.10632, saving model to ./model/287-0.1063.hdf5
#
# Epoch 00288: val_loss did not improve from 0.10632
#
# Epoch 00289: val_loss did not improve from 0.10632
#
# Epoch 00290: val_loss did not improve from 0.10632
#
# Epoch 00291: val_loss did not improve from 0.10632
#
# Epoch 00292: val_loss improved from 0.10632 to 0.10406, saving model to ./model/292-0.1041.hdf5
#
# Epoch 00293: val_loss did not improve from 0.10406
#
# Epoch 00294: val_loss did not improve from 0.10406
#
# Epoch 00295: val_loss did not improve from 0.10406
#
# Epoch 00296: val_loss did not improve from 0.10406
#
# Epoch 00297: val_loss did not improve from 0.10406
#
# Epoch 00298: val_loss did not improve from 0.10406
#
# Epoch 00299: val_loss improved from 0.10406 to 0.10029, saving model to ./model/299-0.1003.hdf5
#
# Epoch 00300: val_loss did not improve from 0.10029
#
# Epoch 00301: val_loss did not improve from 0.10029
#
# Epoch 00302: val_loss did not improve from 0.10029
#
# Epoch 00303: val_loss did not improve from 0.10029
#
# Epoch 00304: val_loss did not improve from 0.10029
#
# Epoch 00305: val_loss did not improve from 0.10029
#
# Epoch 00306: val_loss improved from 0.10029 to 0.09907, saving model to ./model/306-0.0991.hdf5
#
# Epoch 00307: val_loss did not improve from 0.09907
#
# Epoch 00308: val_loss did not improve from 0.09907
#
# Epoch 00309: val_loss did not improve from 0.09907
#
# Epoch 00310: val_loss improved from 0.09907 to 0.09887, saving model to ./model/310-0.0989.hdf5
#
# Epoch 00311: val_loss did not improve from 0.09887
#
# Epoch 00312: val_loss did not improve from 0.09887
#
# Epoch 00313: val_loss did not improve from 0.09887
#
# Epoch 00314: val_loss did not improve from 0.09887
#
# Epoch 00315: val_loss did not improve from 0.09887
#
# Epoch 00316: val_loss did not improve from 0.09887
#
# Epoch 00317: val_loss did not improve from 0.09887
#
# Epoch 00318: val_loss did not improve from 0.09887
#
# Epoch 00319: val_loss did not improve from 0.09887
#
# Epoch 00320: val_loss improved from 0.09887 to 0.09797, saving model to ./model/320-0.0980.hdf5
#
# Epoch 00321: val_loss did not improve from 0.09797
#
# Epoch 00322: val_loss did not improve from 0.09797
#
# Epoch 00323: val_loss improved from 0.09797 to 0.09632, saving model to ./model/323-0.0963.hdf5
#
# Epoch 00324: val_loss did not improve from 0.09632
#
# Epoch 00325: val_loss did not improve from 0.09632
#
# Epoch 00326: val_loss did not improve from 0.09632
#
# Epoch 00327: val_loss did not improve from 0.09632
#
# Epoch 00328: val_loss did not improve from 0.09632
#
# Epoch 00329: val_loss did not improve from 0.09632
#
# Epoch 00330: val_loss improved from 0.09632 to 0.09406, saving model to ./model/330-0.0941.hdf5
#
# Epoch 00331: val_loss did not improve from 0.09406
#
# Epoch 00332: val_loss did not improve from 0.09406
#
# Epoch 00333: val_loss did not improve from 0.09406
#
# Epoch 00334: val_loss improved from 0.09406 to 0.09363, saving model to ./model/334-0.0936.hdf5
#
# Epoch 00335: val_loss did not improve from 0.09363
#
# Epoch 00336: val_loss did not improve from 0.09363
#
# Epoch 00337: val_loss improved from 0.09363 to 0.09174, saving model to ./model/337-0.0917.hdf5
#
# Epoch 00338: val_loss did not improve from 0.09174
#
# Epoch 00339: val_loss did not improve from 0.09174
#
# Epoch 00340: val_loss did not improve from 0.09174
#
# Epoch 00341: val_loss did not improve from 0.09174
#
# Epoch 00342: val_loss did not improve from 0.09174
#
# Epoch 00343: val_loss did not improve from 0.09174
#
# Epoch 00344: val_loss did not improve from 0.09174
#
# Epoch 00345: val_loss did not improve from 0.09174
#
# Epoch 00346: val_loss did not improve from 0.09174
#
# Epoch 00347: val_loss did not improve from 0.09174
#
# Epoch 00348: val_loss did not improve from 0.09174
#
# Epoch 00349: val_loss did not improve from 0.09174
#
# Epoch 00350: val_loss did not improve from 0.09174
#
# Epoch 00351: val_loss did not improve from 0.09174
#
# Epoch 00352: val_loss did not improve from 0.09174
#
# Epoch 00353: val_loss did not improve from 0.09174
#
# Epoch 00354: val_loss did not improve from 0.09174
#
# Epoch 00355: val_loss did not improve from 0.09174
#
# Epoch 00356: val_loss improved from 0.09174 to 0.09095, saving model to ./model/356-0.0910.hdf5
#
# Epoch 00357: val_loss did not improve from 0.09095
#
# Epoch 00358: val_loss did not improve from 0.09095
#
# Epoch 00359: val_loss did not improve from 0.09095
#
# Epoch 00360: val_loss did not improve from 0.09095
#
# Epoch 00361: val_loss did not improve from 0.09095
#
# Epoch 00362: val_loss improved from 0.09095 to 0.08925, saving model to ./model/362-0.0893.hdf5
#
# Epoch 00363: val_loss did not improve from 0.08925
#
# Epoch 00364: val_loss did not improve from 0.08925
#
# Epoch 00365: val_loss did not improve from 0.08925
#
# Epoch 00366: val_loss did not improve from 0.08925
#
# Epoch 00367: val_loss did not improve from 0.08925
#
# Epoch 00368: val_loss did not improve from 0.08925
#
# Epoch 00369: val_loss did not improve from 0.08925
#
# Epoch 00370: val_loss improved from 0.08925 to 0.08673, saving model to ./model/370-0.0867.hdf5
#
# Epoch 00371: val_loss did not improve from 0.08673
#
# Epoch 00372: val_loss did not improve from 0.08673
#
# Epoch 00373: val_loss did not improve from 0.08673
#
# Epoch 00374: val_loss improved from 0.08673 to 0.08518, saving model to ./model/374-0.0852.hdf5
#
# Epoch 00375: val_loss did not improve from 0.08518
#
# Epoch 00376: val_loss did not improve from 0.08518
# Epoch 00377: val_loss did not improve from 0.08518
#
# Epoch 00378: val_loss improved from 0.08518 to 0.08496, saving model to ./model/378-0.0850.hdf5
#
# Epoch 00379: val_loss did not improve from 0.08496
#
# Epoch 00380: val_loss did not improve from 0.08496
#
# Epoch 00381: val_loss did not improve from 0.08496
#
# Epoch 00382: val_loss improved from 0.08496 to 0.08460, saving model to ./model/382-0.0846.hdf5
#
# Epoch 00383: val_loss did not improve from 0.08460
#
# Epoch 00384: val_loss did not improve from 0.08460
#
# Epoch 00385: val_loss did not improve from 0.08460
#
# Epoch 00386: val_loss improved from 0.08460 to 0.08378, saving model to ./model/386-0.0838.hdf5
#
# Epoch 00387: val_loss did not improve from 0.08378
#
# Epoch 00388: val_loss did not improve from 0.08378
#
# Epoch 00389: val_loss did not improve from 0.08378
#
# Epoch 00390: val_loss improved from 0.08378 to 0.08318, saving model to ./model/390-0.0832.hdf5
#
# Epoch 00391: val_loss did not improve from 0.08318
#
# Epoch 00392: val_loss did not improve from 0.08318
#
# Epoch 00393: val_loss did not improve from 0.08318
#
# Epoch 00394: val_loss did not improve from 0.08318
#
# Epoch 00395: val_loss did not improve from 0.08318
#
# Epoch 00396: val_loss did not improve from 0.08318
#
# Epoch 00397: val_loss improved from 0.08318 to 0.08086, saving model to ./model/397-0.0809.hdf5
#
# Epoch 00398: val_loss did not improve from 0.08086
#
# Epoch 00399: val_loss did not improve from 0.08086
#
# Epoch 00400: val_loss did not improve from 0.08086
#
# Epoch 00401: val_loss did not improve from 0.08086
#
# Epoch 00402: val_loss did not improve from 0.08086
#
# Epoch 00403: val_loss improved from 0.08086 to 0.08064, saving model to ./model/403-0.0806.hdf5
#
# Epoch 00404: val_loss did not improve from 0.08064
#
# Epoch 00405: val_loss did not improve from 0.08064
#
# Epoch 00406: val_loss did not improve from 0.08064
#
# Epoch 00407: val_loss improved from 0.08064 to 0.07986, saving model to ./model/407-0.0799.hdf5
#
# Epoch 00408: val_loss did not improve from 0.07986
#
# Epoch 00409: val_loss did not improve from 0.07986
#
# Epoch 00410: val_loss did not improve from 0.07986
#
# Epoch 00411: val_loss did not improve from 0.07986
#
# Epoch 00412: val_loss did not improve from 0.07986
#
# Epoch 00413: val_loss did not improve from 0.07986
#
# Epoch 00414: val_loss did not improve from 0.07986
#
# Epoch 00415: val_loss did not improve from 0.07986
#
# Epoch 00416: val_loss did not improve from 0.07986
#
# Epoch 00417: val_loss did not improve from 0.07986
#
# Epoch 00418: val_loss improved from 0.07986 to 0.07940, saving model to ./model/418-0.0794.hdf5
#
# Epoch 00419: val_loss did not improve from 0.07940
#
# Epoch 00420: val_loss did not improve from 0.07940
#
# Epoch 00421: val_loss improved from 0.07940 to 0.07706, saving model to ./model/421-0.0771.hdf5
#
# Epoch 00422: val_loss did not improve from 0.07706
#
# Epoch 00423: val_loss did not improve from 0.07706
#
# Epoch 00424: val_loss did not improve from 0.07706
#
# Epoch 00425: val_loss improved from 0.07706 to 0.07587, saving model to ./model/425-0.0759.hdf5
#
# Epoch 00426: val_loss did not improve from 0.07587
#
# Epoch 00427: val_loss did not improve from 0.07587
#
# Epoch 00428: val_loss did not improve from 0.07587
#
# Epoch 00429: val_loss improved from 0.07587 to 0.07569, saving model to ./model/429-0.0757.hdf5
#
# Epoch 00430: val_loss did not improve from 0.07569
#
# Epoch 00431: val_loss did not improve from 0.07569
#
# Epoch 00432: val_loss improved from 0.07569 to 0.07519, saving model to ./model/432-0.0752.hdf5
#
# Epoch 00433: val_loss did not improve from 0.07519
#
# Epoch 00434: val_loss did not improve from 0.07519
#
# Epoch 00435: val_loss did not improve from 0.07519
#
# Epoch 00436: val_loss did not improve from 0.07519
#
# Epoch 00437: val_loss did not improve from 0.07519
#
# Epoch 00438: val_loss did not improve from 0.07519
#
# Epoch 00439: val_loss improved from 0.07519 to 0.07466, saving model to ./model/439-0.0747.hdf5
#
# Epoch 00440: val_loss did not improve from 0.07466
#
# Epoch 00441: val_loss did not improve from 0.07466
#
# Epoch 00442: val_loss did not improve from 0.07466
#
# Epoch 00443: val_loss did not improve from 0.07466
#
# Epoch 00444: val_loss did not improve from 0.07466
#
# Epoch 00445: val_loss did not improve from 0.07466
#
# Epoch 00446: val_loss did not improve from 0.07466
#
# Epoch 00447: val_loss did not improve from 0.07466
#
# Epoch 00448: val_loss improved from 0.07466 to 0.07293, saving model to ./model/448-0.0729.hdf5
#
# Epoch 00449: val_loss did not improve from 0.07293
#
# Epoch 00450: val_loss did not improve from 0.07293
#
# Epoch 00451: val_loss did not improve from 0.07293
#
# Epoch 00452: val_loss improved from 0.07293 to 0.07283, saving model to ./model/452-0.0728.hdf5
#
# Epoch 00453: val_loss did not improve from 0.07283
#
# Epoch 00454: val_loss did not improve from 0.07283
#
# Epoch 00455: val_loss did not improve from 0.07283
#
# Epoch 00456: val_loss did not improve from 0.07283
#
# Epoch 00457: val_loss did not improve from 0.07283
#
# Epoch 00458: val_loss did not improve from 0.07283
#
# Epoch 00459: val_loss improved from 0.07283 to 0.07169, saving model to ./model/459-0.0717.hdf5
#
# Epoch 00460: val_loss did not improve from 0.07169
#
# Epoch 00461: val_loss did not improve from 0.07169
#
# Epoch 00462: val_loss did not improve from 0.07169
#
# Epoch 00463: val_loss did not improve from 0.07169
#
# Epoch 00464: val_loss did not improve from 0.07169
#
# Epoch 00465: val_loss did not improve from 0.07169
#
# Epoch 00466: val_loss did not improve from 0.07169
#
# Epoch 00467: val_loss did not improve from 0.07169
#
# Epoch 00468: val_loss did not improve from 0.07169
#
# Epoch 00469: val_loss improved from 0.07169 to 0.07169, saving model to ./model/469-0.0717.hdf5
#
# Epoch 00470: val_loss did not improve from 0.07169
#
# Epoch 00471: val_loss did not improve from 0.07169
#
# Epoch 00472: val_loss did not improve from 0.07169
#
# Epoch 00473: val_loss did not improve from 0.07169
#
# Epoch 00474: val_loss did not improve from 0.07169
#
# Epoch 00475: val_loss improved from 0.07169 to 0.07041, saving model to ./model/475-0.0704.hdf5
#
# Epoch 00476: val_loss did not improve from 0.07041
#
# Epoch 00477: val_loss did not improve from 0.07041
#
# Epoch 00478: val_loss did not improve from 0.07041
#
# Epoch 00479: val_loss did not improve from 0.07041
#
# Epoch 00480: val_loss did not improve from 0.07041
#
# Epoch 00481: val_loss did not improve from 0.07041
#
# Epoch 00482: val_loss did not improve from 0.07041
#
# Epoch 00483: val_loss did not improve from 0.07041
#
# Epoch 00484: val_loss did not improve from 0.07041
#
# Epoch 00485: val_loss did not improve from 0.07041
#
# Epoch 00486: val_loss did not improve from 0.07041
#
# Epoch 00487: val_loss did not improve from 0.07041
#
# Epoch 00488: val_loss improved from 0.07041 to 0.07014, saving model to ./model/488-0.0701.hdf5
#
# Epoch 00489: val_loss did not improve from 0.07014
#
# Epoch 00490: val_loss did not improve from 0.07014
#
# Epoch 00491: val_loss did not improve from 0.07014
#
# Epoch 00492: val_loss improved from 0.07014 to 0.07010, saving model to ./model/492-0.0701.hdf5
#
# Epoch 00493: val_loss did not improve from 0.07010
#
# Epoch 00494: val_loss did not improve from 0.07010
#
# Epoch 00495: val_loss improved from 0.07010 to 0.06981, saving model to ./model/495-0.0698.hdf5
#
# Epoch 00496: val_loss did not improve from 0.06981
#
# Epoch 00497: val_loss did not improve from 0.06981
#
# Epoch 00498: val_loss improved from 0.06981 to 0.06830, saving model to ./model/498-0.0683.hdf5
#
# Epoch 00499: val_loss did not improve from 0.06830
#
# Epoch 00500: val_loss did not improve from 0.06830
#
# Epoch 00501: val_loss did not improve from 0.06830
#
# Epoch 00502: val_loss improved from 0.06830 to 0.06797, saving model to ./model/502-0.0680.hdf5
#
# Epoch 00503: val_loss did not improve from 0.06797
#
# Epoch 00504: val_loss did not improve from 0.06797
#
# Epoch 00505: val_loss did not improve from 0.06797
#
# Epoch 00506: val_loss improved from 0.06797 to 0.06727, saving model to ./model/506-0.0673.hdf5
#
# Epoch 00507: val_loss did not improve from 0.06727
#
# Epoch 00508: val_loss did not improve from 0.06727
#
# Epoch 00509: val_loss did not improve from 0.06727
#
# Epoch 00510: val_loss did not improve from 0.06727
#
# Epoch 00511: val_loss did not improve from 0.06727
#
# Epoch 00512: val_loss did not improve from 0.06727
#
# Epoch 00513: val_loss improved from 0.06727 to 0.06716, saving model to ./model/513-0.0672.hdf5
#
# Epoch 00514: val_loss did not improve from 0.06716
#
# Epoch 00515: val_loss did not improve from 0.06716
#
# Epoch 00516: val_loss improved from 0.06716 to 0.06642, saving model to ./model/516-0.0664.hdf5
#
# Epoch 00517: val_loss did not improve from 0.06642
#
# Epoch 00518: val_loss did not improve from 0.06642
#
# Epoch 00519: val_loss did not improve from 0.06642
#
# Epoch 00520: val_loss did not improve from 0.06642
#
# Epoch 00521: val_loss did not improve from 0.06642
#
# Epoch 00522: val_loss did not improve from 0.06642
#
# Epoch 00523: val_loss improved from 0.06642 to 0.06378, saving model to ./model/523-0.0638.hdf5
#
# Epoch 00524: val_loss did not improve from 0.06378
#
# Epoch 00525: val_loss did not improve from 0.06378
#
# Epoch 00526: val_loss did not improve from 0.06378
#
# Epoch 00527: val_loss improved from 0.06378 to 0.06299, saving model to ./model/527-0.0630.hdf5
#
# Epoch 00528: val_loss did not improve from 0.06299
#
# Epoch 00529: val_loss did not improve from 0.06299
#
# Epoch 00530: val_loss improved from 0.06299 to 0.06259, saving model to ./model/530-0.0626.hdf5
# Epoch 00531: val_loss did not improve from 0.06259
#
# Epoch 00532: val_loss did not improve from 0.06259
#
# Epoch 00533: val_loss did not improve from 0.06259
#
# Epoch 00534: val_loss did not improve from 0.06259
#
# Epoch 00535: val_loss did not improve from 0.06259
#
# Epoch 00536: val_loss did not improve from 0.06259
#
# Epoch 00537: val_loss did not improve from 0.06259
#
# Epoch 00538: val_loss did not improve from 0.06259
#
# Epoch 00539: val_loss did not improve from 0.06259
#
# Epoch 00540: val_loss did not improve from 0.06259
#
# Epoch 00541: val_loss did not improve from 0.06259
#
# Epoch 00542: val_loss did not improve from 0.06259
#
# Epoch 00543: val_loss improved from 0.06259 to 0.06186, saving model to ./model/543-0.0619.hdf5
#
# Epoch 00544: val_loss did not improve from 0.06186
#
# Epoch 00545: val_loss did not improve from 0.06186
#
# Epoch 00546: val_loss did not improve from 0.06186
#
# Epoch 00547: val_loss improved from 0.06186 to 0.06165, saving model to ./model/547-0.0617.hdf5
#
# Epoch 00548: val_loss did not improve from 0.06165
#
# Epoch 00549: val_loss did not improve from 0.06165
#
# Epoch 00550: val_loss did not improve from 0.06165
#
# Epoch 00551: val_loss did not improve from 0.06165
#
# Epoch 00552: val_loss did not improve from 0.06165
#
# Epoch 00553: val_loss improved from 0.06165 to 0.06161, saving model to ./model/553-0.0616.hdf5
#
# Epoch 00554: val_loss improved from 0.06161 to 0.06118, saving model to ./model/554-0.0612.hdf5
#
# Epoch 00555: val_loss did not improve from 0.06118
#
# Epoch 00556: val_loss did not improve from 0.06118
#
# Epoch 00557: val_loss did not improve from 0.06118
#
# Epoch 00558: val_loss did not improve from 0.06118
#
# Epoch 00559: val_loss did not improve from 0.06118
#
# Epoch 00560: val_loss improved from 0.06118 to 0.06067, saving model to ./model/560-0.0607.hdf5
#
# Epoch 00561: val_loss did not improve from 0.06067
#
# Epoch 00562: val_loss did not improve from 0.06067
#
# Epoch 00563: val_loss did not improve from 0.06067
#
# Epoch 00564: val_loss did not improve from 0.06067
#
# Epoch 00565: val_loss did not improve from 0.06067
#
# Epoch 00566: val_loss improved from 0.06067 to 0.06053, saving model to ./model/566-0.0605.hdf5
#
# Epoch 00567: val_loss did not improve from 0.06053
#
# Epoch 00568: val_loss did not improve from 0.06053
#
# Epoch 00569: val_loss did not improve from 0.06053
#
# Epoch 00570: val_loss did not improve from 0.06053
#
# Epoch 00571: val_loss did not improve from 0.06053
#
# Epoch 00572: val_loss did not improve from 0.06053
#
# Epoch 00573: val_loss did not improve from 0.06053
#
# Epoch 00574: val_loss improved from 0.06053 to 0.05962, saving model to ./model/574-0.0596.hdf5
#
# Epoch 00575: val_loss did not improve from 0.05962
#
# Epoch 00576: val_loss did not improve from 0.05962
#
# Epoch 00577: val_loss improved from 0.05962 to 0.05940, saving model to ./model/577-0.0594.hdf5
#
# Epoch 00578: val_loss improved from 0.05940 to 0.05894, saving model to ./model/578-0.0589.hdf5
#
# Epoch 00579: val_loss did not improve from 0.05894
#
# Epoch 00580: val_loss improved from 0.05894 to 0.05733, saving model to ./model/580-0.0573.hdf5
#
# Epoch 00581: val_loss did not improve from 0.05733
#
# Epoch 00582: val_loss did not improve from 0.05733
#
# Epoch 00583: val_loss did not improve from 0.05733
#
# Epoch 00584: val_loss did not improve from 0.05733
#
# Epoch 00585: val_loss did not improve from 0.05733
#
# Epoch 00586: val_loss did not improve from 0.05733
#
# Epoch 00587: val_loss did not improve from 0.05733
#
# Epoch 00588: val_loss did not improve from 0.05733
#
# Epoch 00589: val_loss did not improve from 0.05733
#
# Epoch 00590: val_loss did not improve from 0.05733
#
# Epoch 00591: val_loss did not improve from 0.05733
#
# Epoch 00592: val_loss did not improve from 0.05733
#
# Epoch 00593: val_loss did not improve from 0.05733
#
# Epoch 00594: val_loss did not improve from 0.05733
#
# Epoch 00595: val_loss did not improve from 0.05733
#
# Epoch 00596: val_loss did not improve from 0.05733
#
# Epoch 00597: val_loss did not improve from 0.05733
#
# Epoch 00598: val_loss improved from 0.05733 to 0.05669, saving model to ./model/598-0.0567.hdf5
#
# Epoch 00599: val_loss did not improve from 0.05669
#
# Epoch 00600: val_loss did not improve from 0.05669
#
# Epoch 00601: val_loss did not improve from 0.05669
#
# Epoch 00602: val_loss did not improve from 0.05669
#
# Epoch 00603: val_loss did not improve from 0.05669
#
# Epoch 00604: val_loss improved from 0.05669 to 0.05667, saving model to ./model/604-0.0567.hdf5
#
# Epoch 00605: val_loss did not improve from 0.05667
#
# Epoch 00606: val_loss did not improve from 0.05667
#
# Epoch 00607: val_loss improved from 0.05667 to 0.05645, saving model to ./model/607-0.0565.hdf5
#
# Epoch 00608: val_loss did not improve from 0.05645
#
# Epoch 00609: val_loss did not improve from 0.05645
#
# Epoch 00610: val_loss did not improve from 0.05645
#
# Epoch 00611: val_loss improved from 0.05645 to 0.05572, saving model to ./model/611-0.0557.hdf5
#
# Epoch 00612: val_loss did not improve from 0.05572
#
# Epoch 00613: val_loss did not improve from 0.05572
#
# Epoch 00614: val_loss improved from 0.05572 to 0.05534, saving model to ./model/614-0.0553.hdf5
#
# Epoch 00615: val_loss did not improve from 0.05534
#
# Epoch 00616: val_loss did not improve from 0.05534
#
# Epoch 00617: val_loss did not improve from 0.05534
#
# Epoch 00618: val_loss improved from 0.05534 to 0.05500, saving model to ./model/618-0.0550.hdf5
#
# Epoch 00619: val_loss did not improve from 0.05500
#
# Epoch 00620: val_loss did not improve from 0.05500
#
# Epoch 00621: val_loss improved from 0.05500 to 0.05466, saving model to ./model/621-0.0547.hdf5
#
# Epoch 00622: val_loss did not improve from 0.05466
#
# Epoch 00623: val_loss did not improve from 0.05466
#
# Epoch 00624: val_loss improved from 0.05466 to 0.05460, saving model to ./model/624-0.0546.hdf5
#
# Epoch 00625: val_loss improved from 0.05460 to 0.05341, saving model to ./model/625-0.0534.hdf5
#
# Epoch 00626: val_loss did not improve from 0.05341
#
# Epoch 00627: val_loss did not improve from 0.05341
#
# Epoch 00628: val_loss improved from 0.05341 to 0.05310, saving model to ./model/628-0.0531.hdf5
#
# Epoch 00629: val_loss did not improve from 0.05310
#
# Epoch 00630: val_loss did not improve from 0.05310
#
# Epoch 00631: val_loss did not improve from 0.05310
#
# Epoch 00632: val_loss did not improve from 0.05310
#
# Epoch 00633: val_loss did not improve from 0.05310
#
# Epoch 00634: val_loss did not improve from 0.05310
#
# Epoch 00635: val_loss did not improve from 0.05310
#
# Epoch 00636: val_loss did not improve from 0.05310
#
# Epoch 00637: val_loss did not improve from 0.05310
#
# Epoch 00638: val_loss did not improve from 0.05310
#
# Epoch 00639: val_loss did not improve from 0.05310
#
# Epoch 00640: val_loss did not improve from 0.05310
#
# Epoch 00641: val_loss did not improve from 0.05310
#
# Epoch 00642: val_loss did not improve from 0.05310
#
# Epoch 00643: val_loss did not improve from 0.05310
#
# Epoch 00644: val_loss did not improve from 0.05310
#
# Epoch 00645: val_loss improved from 0.05310 to 0.05277, saving model to ./model/645-0.0528.hdf5
#
# Epoch 00646: val_loss did not improve from 0.05277
#
# Epoch 00647: val_loss did not improve from 0.05277
#
# Epoch 00648: val_loss improved from 0.05277 to 0.05229, saving model to ./model/648-0.0523.hdf5
#
# Epoch 00649: val_loss did not improve from 0.05229
#
# Epoch 00650: val_loss did not improve from 0.05229
#
# Epoch 00651: val_loss did not improve from 0.05229
#
# Epoch 00652: val_loss did not improve from 0.05229
#
# Epoch 00653: val_loss did not improve from 0.05229
#
# Epoch 00654: val_loss did not improve from 0.05229
#
# Epoch 00655: val_loss did not improve from 0.05229
#
# Epoch 00656: val_loss did not improve from 0.05229
#
# Epoch 00657: val_loss did not improve from 0.05229
#
# Epoch 00658: val_loss did not improve from 0.05229
#
# Epoch 00659: val_loss did not improve from 0.05229
#
# Epoch 00660: val_loss did not improve from 0.05229
#
# Epoch 00661: val_loss did not improve from 0.05229
#
# Epoch 00662: val_loss improved from 0.05229 to 0.05116, saving model to ./model/662-0.0512.hdf5
#
# Epoch 00663: val_loss did not improve from 0.05116
#
# Epoch 00664: val_loss did not improve from 0.05116
#
# Epoch 00665: val_loss did not improve from 0.05116
#
# Epoch 00666: val_loss did not improve from 0.05116
#
# Epoch 00667: val_loss did not improve from 0.05116
#
# Epoch 00668: val_loss did not improve from 0.05116
#
# Epoch 00669: val_loss improved from 0.05116 to 0.05071, saving model to ./model/669-0.0507.hdf5
#
# Epoch 00670: val_loss did not improve from 0.05071
#
# Epoch 00671: val_loss improved from 0.05071 to 0.04991, saving model to ./model/671-0.0499.hdf5
# Epoch 00672: val_loss did not improve from 0.04991
#
# Epoch 00673: val_loss did not improve from 0.04991
#
# Epoch 00674: val_loss did not improve from 0.04991
#
# Epoch 00675: val_loss did not improve from 0.04991
#
# Epoch 00676: val_loss did not improve from 0.04991
#
# Epoch 00677: val_loss improved from 0.04991 to 0.04880, saving model to ./model/677-0.0488.hdf5
#
# Epoch 00678: val_loss did not improve from 0.04880
#
# Epoch 00679: val_loss did not improve from 0.04880
#
# Epoch 00680: val_loss improved from 0.04880 to 0.04871, saving model to ./model/680-0.0487.hdf5
#
# Epoch 00681: val_loss did not improve from 0.04871
#
# Epoch 00682: val_loss did not improve from 0.04871
#
# Epoch 00683: val_loss did not improve from 0.04871
#
# Epoch 00684: val_loss did not improve from 0.04871
#
# Epoch 00685: val_loss did not improve from 0.04871
#
# Epoch 00686: val_loss did not improve from 0.04871
#
# Epoch 00687: val_loss did not improve from 0.04871
#
# Epoch 00688: val_loss did not improve from 0.04871
#
# Epoch 00689: val_loss did not improve from 0.04871
#
# Epoch 00690: val_loss did not improve from 0.04871
#
# Epoch 00691: val_loss did not improve from 0.04871
#
# Epoch 00692: val_loss did not improve from 0.04871
#
# Epoch 00693: val_loss did not improve from 0.04871
#
# Epoch 00694: val_loss improved from 0.04871 to 0.04819, saving model to ./model/694-0.0482.hdf5
#
# Epoch 00695: val_loss did not improve from 0.04819
#
# Epoch 00696: val_loss did not improve from 0.04819
#
# Epoch 00697: val_loss did not improve from 0.04819
#
# Epoch 00698: val_loss improved from 0.04819 to 0.04651, saving model to ./model/698-0.0465.hdf5
#
# Epoch 00699: val_loss improved from 0.04651 to 0.04621, saving model to ./model/699-0.0462.hdf5
#
# Epoch 00700: val_loss did not improve from 0.04621
#
# Epoch 00701: val_loss improved from 0.04621 to 0.04516, saving model to ./model/701-0.0452.hdf5
#
# Epoch 00702: val_loss improved from 0.04516 to 0.04439, saving model to ./model/702-0.0444.hdf5
#
# Epoch 00703: val_loss did not improve from 0.04439
#
# Epoch 00704: val_loss did not improve from 0.04439
#
# Epoch 00705: val_loss improved from 0.04439 to 0.04194, saving model to ./model/705-0.0419.hdf5
#
# Epoch 00706: val_loss improved from 0.04194 to 0.04099, saving model to ./model/706-0.0410.hdf5
#
# Epoch 00707: val_loss did not improve from 0.04099
#
# Epoch 00708: val_loss did not improve from 0.04099
#
# Epoch 00709: val_loss did not improve from 0.04099
#
# Epoch 00710: val_loss did not improve from 0.04099
#
# Epoch 00711: val_loss did not improve from 0.04099
#
# Epoch 00712: val_loss did not improve from 0.04099
#
# Epoch 00713: val_loss did not improve from 0.04099
#
# Epoch 00714: val_loss did not improve from 0.04099
#
# Epoch 00715: val_loss did not improve from 0.04099
#
# Epoch 00716: val_loss did not improve from 0.04099
#
# Epoch 00717: val_loss did not improve from 0.04099
#
# Epoch 00718: val_loss did not improve from 0.04099
#
# Epoch 00719: val_loss did not improve from 0.04099
#
# Epoch 00720: val_loss did not improve from 0.04099
#
# Epoch 00721: val_loss did not improve from 0.04099
#
# Epoch 00722: val_loss did not improve from 0.04099
#
# Epoch 00723: val_loss did not improve from 0.04099
#
# Epoch 00724: val_loss did not improve from 0.04099
#
# Epoch 00725: val_loss did not improve from 0.04099
#
# Epoch 00726: val_loss did not improve from 0.04099
#
# Epoch 00727: val_loss did not improve from 0.04099
#
# Epoch 00728: val_loss did not improve from 0.04099
#
# Epoch 00729: val_loss did not improve from 0.04099
#
# Epoch 00730: val_loss did not improve from 0.04099
#
# Epoch 00731: val_loss did not improve from 0.04099
#
# Epoch 00732: val_loss did not improve from 0.04099
#
# Epoch 00733: val_loss did not improve from 0.04099
#
# Epoch 00734: val_loss did not improve from 0.04099
#
# Epoch 00735: val_loss did not improve from 0.04099
#
# Epoch 00736: val_loss did not improve from 0.04099
#
# Epoch 00737: val_loss did not improve from 0.04099
#
# Epoch 00738: val_loss did not improve from 0.04099
#
# Epoch 00739: val_loss did not improve from 0.04099
#
# Epoch 00740: val_loss did not improve from 0.04099
#
# Epoch 00741: val_loss did not improve from 0.04099
#
# Epoch 00742: val_loss did not improve from 0.04099
#
# Epoch 00743: val_loss did not improve from 0.04099
#
# Epoch 00744: val_loss did not improve from 0.04099
#
# Epoch 00745: val_loss did not improve from 0.04099
#
# Epoch 00746: val_loss did not improve from 0.04099
#
# Epoch 00747: val_loss did not improve from 0.04099
#
# Epoch 00748: val_loss did not improve from 0.04099
#
# Epoch 00749: val_loss did not improve from 0.04099
#
# Epoch 00750: val_loss did not improve from 0.04099
#
# Epoch 00751: val_loss did not improve from 0.04099
#
# Epoch 00752: val_loss did not improve from 0.04099
#
# Epoch 00753: val_loss did not improve from 0.04099
#
# Epoch 00754: val_loss did not improve from 0.04099
#
# Epoch 00755: val_loss did not improve from 0.04099
#
# Epoch 00756: val_loss did not improve from 0.04099
#
# Epoch 00757: val_loss did not improve from 0.04099
#
# Epoch 00758: val_loss did not improve from 0.04099
#
# Epoch 00759: val_loss did not improve from 0.04099
#
# Epoch 00760: val_loss did not improve from 0.04099
#
# Epoch 00761: val_loss did not improve from 0.04099
#
# Epoch 00762: val_loss did not improve from 0.04099
#
# Epoch 00763: val_loss did not improve from 0.04099
#
# Epoch 00764: val_loss did not improve from 0.04099
#
# Epoch 00765: val_loss did not improve from 0.04099
#
# Epoch 00766: val_loss did not improve from 0.04099
#
# Epoch 00767: val_loss did not improve from 0.04099
#
# Epoch 00768: val_loss did not improve from 0.04099
#
# Epoch 00769: val_loss did not improve from 0.04099
#
# Epoch 00770: val_loss did not improve from 0.04099
#
# Epoch 00771: val_loss did not improve from 0.04099
#
# Epoch 00772: val_loss did not improve from 0.04099
#
# Epoch 00773: val_loss did not improve from 0.04099
#
# Epoch 00774: val_loss did not improve from 0.04099
#
# Epoch 00775: val_loss did not improve from 0.04099
#
# Epoch 00776: val_loss did not improve from 0.04099
#
# Epoch 00777: val_loss did not improve from 0.04099
#
# Epoch 00778: val_loss did not improve from 0.04099
#
# Epoch 00779: val_loss did not improve from 0.04099
#
# Epoch 00780: val_loss did not improve from 0.04099
#
# Epoch 00781: val_loss did not improve from 0.04099
#
# Epoch 00782: val_loss did not improve from 0.04099
#
# Epoch 00783: val_loss did not improve from 0.04099
#
# Epoch 00784: val_loss did not improve from 0.04099
#
# Epoch 00785: val_loss did not improve from 0.04099
#
# Epoch 00786: val_loss did not improve from 0.04099
#
# Epoch 00787: val_loss did not improve from 0.04099
#
# Epoch 00788: val_loss did not improve from 0.04099
#
# Epoch 00789: val_loss did not improve from 0.04099
#
# Epoch 00790: val_loss did not improve from 0.04099
#
# Epoch 00791: val_loss did not improve from 0.04099
#
# Epoch 00792: val_loss did not improve from 0.04099
#
# Epoch 00793: val_loss did not improve from 0.04099
#
# Epoch 00794: val_loss did not improve from 0.04099
#
# Epoch 00795: val_loss did not improve from 0.04099
#
# Epoch 00796: val_loss did not improve from 0.04099
#
# Epoch 00797: val_loss did not improve from 0.04099
#
# Epoch 00798: val_loss did not improve from 0.04099
#
# Epoch 00799: val_loss did not improve from 0.04099
#
# Epoch 00800: val_loss did not improve from 0.04099
#
# Epoch 00801: val_loss did not improve from 0.04099
#
# Epoch 00802: val_loss did not improve from 0.04099
#
# Epoch 00803: val_loss did not improve from 0.04099
#
# Epoch 00804: val_loss did not improve from 0.04099
#
# Epoch 00805: val_loss did not improve from 0.04099
#
# Epoch 00806: val_loss did not improve from 0.04099
