# %%
from keras.models import Sequential, load_model
from keras.layers.core import Dense
from keras.callbacks import ModelCheckpoint

import pandas as pd
import numpy as np
import os
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
df_pre = pd.read_csv('wine.csv', header=None)
df = df_pre.sample(frac=1)

# %%
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])

# %%
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

# %%
modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# %%
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])
# Out:
# WARNING:tensorflow:From C:\Users\ai\Anaconda3\envs\mlpy36\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# Epoch 00001: val_loss improved from inf to 0.30997, saving model to ./model/01-0.3100.hdf5
#
# Epoch 00002: val_loss improved from 0.30997 to 0.25170, saving model to ./model/02-0.2517.hdf5
#
# Epoch 00003: val_loss improved from 0.25170 to 0.21348, saving model to ./model/03-0.2135.hdf5
#
# Epoch 00004: val_loss improved from 0.21348 to 0.20470, saving model to ./model/04-0.2047.hdf5
#
# Epoch 00005: val_loss improved from 0.20470 to 0.19705, saving model to ./model/05-0.1970.hdf5
#
# Epoch 00006: val_loss improved from 0.19705 to 0.18635, saving model to ./model/06-0.1864.hdf5
#
# Epoch 00007: val_loss improved from 0.18635 to 0.18076, saving model to ./model/07-0.1808.hdf5
#
# Epoch 00008: val_loss improved from 0.18076 to 0.18023, saving model to ./model/08-0.1802.hdf5
#
# Epoch 00009: val_loss improved from 0.18023 to 0.17980, saving model to ./model/09-0.1798.hdf5
#
# Epoch 00010: val_loss improved from 0.17980 to 0.17678, saving model to ./model/10-0.1768.hdf5
#
# Epoch 00011: val_loss improved from 0.17678 to 0.16680, saving model to ./model/11-0.1668.hdf5
#
# Epoch 00012: val_loss improved from 0.16680 to 0.16345, saving model to ./model/12-0.1635.hdf5
#
# Epoch 00013: val_loss did not improve from 0.16345
#
# Epoch 00014: val_loss improved from 0.16345 to 0.15829, saving model to ./model/14-0.1583.hdf5
#
# Epoch 00015: val_loss improved from 0.15829 to 0.15697, saving model to ./model/15-0.1570.hdf5
#
# Epoch 00016: val_loss improved from 0.15697 to 0.15140, saving model to ./model/16-0.1514.hdf5
#
# Epoch 00017: val_loss improved from 0.15140 to 0.14853, saving model to ./model/17-0.1485.hdf5
#
# Epoch 00018: val_loss improved from 0.14853 to 0.14651, saving model to ./model/18-0.1465.hdf5
#
# Epoch 00019: val_loss improved from 0.14651 to 0.14324, saving model to ./model/19-0.1432.hdf5
#
# Epoch 00020: val_loss did not improve from 0.14324
#
# Epoch 00021: val_loss improved from 0.14324 to 0.13687, saving model to ./model/21-0.1369.hdf5
#
# Epoch 00022: val_loss improved from 0.13687 to 0.13416, saving model to ./model/22-0.1342.hdf5
#
# Epoch 00023: val_loss did not improve from 0.13416
#
# Epoch 00024: val_loss improved from 0.13416 to 0.12894, saving model to ./model/24-0.1289.hdf5
#
# Epoch 00025: val_loss improved from 0.12894 to 0.12750, saving model to ./model/25-0.1275.hdf5
#
# Epoch 00026: val_loss improved from 0.12750 to 0.12335, saving model to ./model/26-0.1233.hdf5
#
# Epoch 00027: val_loss improved from 0.12335 to 0.12301, saving model to ./model/27-0.1230.hdf5
#
# Epoch 00028: val_loss improved from 0.12301 to 0.11748, saving model to ./model/28-0.1175.hdf5
#
# Epoch 00029: val_loss did not improve from 0.11748
#
# Epoch 00030: val_loss improved from 0.11748 to 0.11273, saving model to ./model/30-0.1127.hdf5
#
# Epoch 00031: val_loss improved from 0.11273 to 0.11197, saving model to ./model/31-0.1120.hdf5
#
# Epoch 00032: val_loss improved from 0.11197 to 0.10941, saving model to ./model/32-0.1094.hdf5
#
# Epoch 00033: val_loss did not improve from 0.10941
#
# Epoch 00034: val_loss did not improve from 0.10941
#
# Epoch 00035: val_loss improved from 0.10941 to 0.10175, saving model to ./model/35-0.1018.hdf5
#
# Epoch 00036: val_loss did not improve from 0.10175
#
# Epoch 00037: val_loss improved from 0.10175 to 0.09904, saving model to ./model/37-0.0990.hdf5
#
# Epoch 00038: val_loss improved from 0.09904 to 0.09767, saving model to ./model/38-0.0977.hdf5
#
# Epoch 00039: val_loss improved from 0.09767 to 0.09623, saving model to ./model/39-0.0962.hdf5
#
# Epoch 00040: val_loss improved from 0.09623 to 0.09106, saving model to ./model/40-0.0911.hdf5
#
# Epoch 00041: val_loss did not improve from 0.09106
#
# Epoch 00042: val_loss improved from 0.09106 to 0.08742, saving model to ./model/42-0.0874.hdf5
#
# Epoch 00043: val_loss improved from 0.08742 to 0.08520, saving model to ./model/43-0.0852.hdf5
#
# Epoch 00044: val_loss improved from 0.08520 to 0.08412, saving model to ./model/44-0.0841.hdf5
#
# Epoch 00045: val_loss improved from 0.08412 to 0.08179, saving model to ./model/45-0.0818.hdf5
#
# Epoch 00046: val_loss improved from 0.08179 to 0.08111, saving model to ./model/46-0.0811.hdf5
#
# Epoch 00047: val_loss improved from 0.08111 to 0.07912, saving model to ./model/47-0.0791.hdf5
#
# Epoch 00048: val_loss did not improve from 0.07912
#
# Epoch 00049: val_loss improved from 0.07912 to 0.07870, saving model to ./model/49-0.0787.hdf5
#
# Epoch 00050: val_loss improved from 0.07870 to 0.07758, saving model to ./model/50-0.0776.hdf5
#
# Epoch 00051: val_loss did not improve from 0.07758
#
# Epoch 00052: val_loss improved from 0.07758 to 0.07708, saving model to ./model/52-0.0771.hdf5
#
# Epoch 00053: val_loss did not improve from 0.07708
#
# Epoch 00054: val_loss did not improve from 0.07708
#
# Epoch 00055: val_loss did not improve from 0.07708
#
# Epoch 00056: val_loss did not improve from 0.07708
#
# Epoch 00057: val_loss improved from 0.07708 to 0.07149, saving model to ./model/57-0.0715.hdf5
#
# Epoch 00058: val_loss did not improve from 0.07149
#
# Epoch 00059: val_loss improved from 0.07149 to 0.06847, saving model to ./model/59-0.0685.hdf5
#
# Epoch 00060: val_loss did not improve from 0.06847
#
# Epoch 00061: val_loss did not improve from 0.06847
#
# Epoch 00062: val_loss improved from 0.06847 to 0.06828, saving model to ./model/62-0.0683.hdf5
#
# Epoch 00063: val_loss improved from 0.06828 to 0.06654, saving model to ./model/63-0.0665.hdf5
#
# Epoch 00064: val_loss did not improve from 0.06654
#
# Epoch 00065: val_loss did not improve from 0.06654
#
# Epoch 00066: val_loss improved from 0.06654 to 0.06491, saving model to ./model/66-0.0649.hdf5
#
# Epoch 00067: val_loss improved from 0.06491 to 0.06440, saving model to ./model/67-0.0644.hdf5
#
# Epoch 00068: val_loss did not improve from 0.06440
#
# Epoch 00069: val_loss improved from 0.06440 to 0.06335, saving model to ./model/69-0.0634.hdf5
#
# Epoch 00070: val_loss improved from 0.06335 to 0.06327, saving model to ./model/70-0.0633.hdf5
#
# Epoch 00071: val_loss did not improve from 0.06327
#
# Epoch 00072: val_loss improved from 0.06327 to 0.06100, saving model to ./model/72-0.0610.hdf5
#
# Epoch 00073: val_loss did not improve from 0.06100
#
# Epoch 00074: val_loss did not improve from 0.06100
#
# Epoch 00075: val_loss did not improve from 0.06100
#
# Epoch 00076: val_loss did not improve from 0.06100
#
# Epoch 00077: val_loss did not improve from 0.06100
#
# Epoch 00078: val_loss did not improve from 0.06100
#
# Epoch 00079: val_loss did not improve from 0.06100
#
# Epoch 00080: val_loss did not improve from 0.06100
#
# Epoch 00081: val_loss did not improve from 0.06100
#
# Epoch 00082: val_loss did not improve from 0.06100
#
# Epoch 00083: val_loss did not improve from 0.06100
#
# Epoch 00084: val_loss did not improve from 0.06100
#
# Epoch 00085: val_loss improved from 0.06100 to 0.05792, saving model to ./model/85-0.0579.hdf5
#
# Epoch 00086: val_loss did not improve from 0.05792
#
# Epoch 00087: val_loss improved from 0.05792 to 0.05634, saving model to ./model/87-0.0563.hdf5
#
# Epoch 00088: val_loss did not improve from 0.05634
#
# Epoch 00089: val_loss did not improve from 0.05634
#
# Epoch 00090: val_loss did not improve from 0.05634
#
# Epoch 00091: val_loss did not improve from 0.05634
#
# Epoch 00092: val_loss improved from 0.05634 to 0.05633, saving model to ./model/92-0.0563.hdf5
#
# Epoch 00093: val_loss did not improve from 0.05633
#
# Epoch 00094: val_loss did not improve from 0.05633
#
# Epoch 00095: val_loss did not improve from 0.05633
#
# Epoch 00096: val_loss did not improve from 0.05633
#
# Epoch 00097: val_loss improved from 0.05633 to 0.05447, saving model to ./model/97-0.0545.hdf5
#
# Epoch 00098: val_loss did not improve from 0.05447
#
# Epoch 00099: val_loss did not improve from 0.05447
#
# Epoch 00100: val_loss did not improve from 0.05447
#
# Epoch 00101: val_loss did not improve from 0.05447
#
# Epoch 00102: val_loss did not improve from 0.05447
#
# Epoch 00103: val_loss did not improve from 0.05447
#
# Epoch 00104: val_loss did not improve from 0.05447
#
# Epoch 00105: val_loss did not improve from 0.05447
#
# Epoch 00106: val_loss did not improve from 0.05447
#
# Epoch 00107: val_loss did not improve from 0.05447
#
# Epoch 00108: val_loss did not improve from 0.05447
#
# Epoch 00109: val_loss improved from 0.05447 to 0.05431, saving model to ./model/109-0.0543.hdf5
# Epoch 00110: val_loss did not improve from 0.05431
#
# Epoch 00111: val_loss did not improve from 0.05431
#
# Epoch 00112: val_loss did not improve from 0.05431
#
# Epoch 00113: val_loss improved from 0.05431 to 0.05320, saving model to ./model/113-0.0532.hdf5
#
# Epoch 00114: val_loss did not improve from 0.05320
#
# Epoch 00115: val_loss did not improve from 0.05320
#
# Epoch 00116: val_loss did not improve from 0.05320
#
# Epoch 00117: val_loss improved from 0.05320 to 0.05291, saving model to ./model/117-0.0529.hdf5
#
# Epoch 00118: val_loss did not improve from 0.05291
#
# Epoch 00119: val_loss did not improve from 0.05291
#
# Epoch 00120: val_loss did not improve from 0.05291
#
# Epoch 00121: val_loss improved from 0.05291 to 0.05203, saving model to ./model/121-0.0520.hdf5
#
# Epoch 00122: val_loss did not improve from 0.05203
#
# Epoch 00123: val_loss did not improve from 0.05203
#
# Epoch 00124: val_loss did not improve from 0.05203
#
# Epoch 00125: val_loss did not improve from 0.05203
#
# Epoch 00126: val_loss did not improve from 0.05203
#
# Epoch 00127: val_loss did not improve from 0.05203
#
# Epoch 00128: val_loss improved from 0.05203 to 0.05188, saving model to ./model/128-0.0519.hdf5
#
# Epoch 00129: val_loss did not improve from 0.05188
#
# Epoch 00130: val_loss did not improve from 0.05188
#
# Epoch 00131: val_loss did not improve from 0.05188
#
# Epoch 00132: val_loss did not improve from 0.05188
#
# Epoch 00133: val_loss did not improve from 0.05188
#
# Epoch 00134: val_loss did not improve from 0.05188
#
# Epoch 00135: val_loss did not improve from 0.05188
#
# Epoch 00136: val_loss did not improve from 0.05188
#
# Epoch 00137: val_loss improved from 0.05188 to 0.05126, saving model to ./model/137-0.0513.hdf5
#
# Epoch 00138: val_loss improved from 0.05126 to 0.05095, saving model to ./model/138-0.0510.hdf5
#
# Epoch 00139: val_loss did not improve from 0.05095
#
# Epoch 00140: val_loss improved from 0.05095 to 0.05093, saving model to ./model/140-0.0509.hdf5
#
# Epoch 00141: val_loss did not improve from 0.05093
#
# Epoch 00142: val_loss did not improve from 0.05093
#
# Epoch 00143: val_loss improved from 0.05093 to 0.05053, saving model to ./model/143-0.0505.hdf5
#
# Epoch 00144: val_loss did not improve from 0.05053
#
# Epoch 00145: val_loss improved from 0.05053 to 0.05038, saving model to ./model/145-0.0504.hdf5
#
# Epoch 00146: val_loss did not improve from 0.05038
#
# Epoch 00147: val_loss did not improve from 0.05038
#
# Epoch 00148: val_loss did not improve from 0.05038
#
# Epoch 00149: val_loss did not improve from 0.05038
#
# Epoch 00150: val_loss did not improve from 0.05038
#
# Epoch 00151: val_loss did not improve from 0.05038
#
# Epoch 00152: val_loss did not improve from 0.05038
#
# Epoch 00153: val_loss improved from 0.05038 to 0.05024, saving model to ./model/153-0.0502.hdf5
#
# Epoch 00154: val_loss did not improve from 0.05024
#
# Epoch 00155: val_loss did not improve from 0.05024
#
# Epoch 00156: val_loss did not improve from 0.05024
#
# Epoch 00157: val_loss did not improve from 0.05024
#
# Epoch 00158: val_loss did not improve from 0.05024
#
# Epoch 00159: val_loss improved from 0.05024 to 0.05009, saving model to ./model/159-0.0501.hdf5
#
# Epoch 00160: val_loss did not improve from 0.05009
#
# Epoch 00161: val_loss improved from 0.05009 to 0.05005, saving model to ./model/161-0.0500.hdf5
#
# Epoch 00162: val_loss did not improve from 0.05005
#
# Epoch 00163: val_loss did not improve from 0.05005
#
# Epoch 00164: val_loss did not improve from 0.05005
#
# Epoch 00165: val_loss did not improve from 0.05005
#
# Epoch 00166: val_loss improved from 0.05005 to 0.04998, saving model to ./model/166-0.0500.hdf5
#
# Epoch 00167: val_loss improved from 0.04998 to 0.04971, saving model to ./model/167-0.0497.hdf5
#
# Epoch 00168: val_loss did not improve from 0.04971
#
# Epoch 00169: val_loss did not improve from 0.04971
#
# Epoch 00170: val_loss did not improve from 0.04971
#
# Epoch 00171: val_loss did not improve from 0.04971
#
# Epoch 00172: val_loss improved from 0.04971 to 0.04856, saving model to ./model/172-0.0486.hdf5
#
# Epoch 00173: val_loss did not improve from 0.04856
#
# Epoch 00174: val_loss did not improve from 0.04856
#
# Epoch 00175: val_loss did not improve from 0.04856
#
# Epoch 00176: val_loss did not improve from 0.04856
#
# Epoch 00177: val_loss did not improve from 0.04856
#
# Epoch 00178: val_loss did not improve from 0.04856
#
# Epoch 00179: val_loss did not improve from 0.04856
#
# Epoch 00180: val_loss did not improve from 0.04856
#
# Epoch 00181: val_loss did not improve from 0.04856
#
# Epoch 00182: val_loss did not improve from 0.04856
#
# Epoch 00183: val_loss did not improve from 0.04856
#
# Epoch 00184: val_loss did not improve from 0.04856
#
# Epoch 00185: val_loss did not improve from 0.04856
#
# Epoch 00186: val_loss did not improve from 0.04856
#
# Epoch 00187: val_loss did not improve from 0.04856
#
# Epoch 00188: val_loss did not improve from 0.04856
#
# Epoch 00189: val_loss did not improve from 0.04856
#
# Epoch 00190: val_loss did not improve from 0.04856
#
# Epoch 00191: val_loss did not improve from 0.04856
#
# Epoch 00192: val_loss did not improve from 0.04856
#
# Epoch 00193: val_loss did not improve from 0.04856
#
# Epoch 00194: val_loss improved from 0.04856 to 0.04719, saving model to ./model/194-0.0472.hdf5
#
# Epoch 00195: val_loss did not improve from 0.04719
#
# Epoch 00196: val_loss did not improve from 0.04719
#
# Epoch 00197: val_loss did not improve from 0.04719
#
# Epoch 00198: val_loss did not improve from 0.04719
#
# Epoch 00199: val_loss did not improve from 0.04719
#
# Epoch 00200: val_loss did not improve from 0.04719
