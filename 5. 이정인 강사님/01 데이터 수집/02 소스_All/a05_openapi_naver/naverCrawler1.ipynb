# %%
import urllib.request
import config

def makeURL(sNode, search_text ):
    base = "https://openapi.naver.com/v1/search"
    node = "/%s.json" % sNode
    parameters = "?query=%s" % urllib.parse.quote(search_text) 
    url = base + node + parameters
    return url

def requestURL(url):
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", config.client_id)  # open api 키를 header에 추가
    req.add_header("X-Naver-Client-Secret", config.client_secret)  # open api 키를 header에 추가
    try:
        response = urllib.request.urlopen(req)  # 크롤링
        if response.status == 200:  # 200이면 정상 응답
            print("Url Request Success")
            data = response.read().decode('utf-8')
            return data  # 크롤링 결과 반환
    except Exception as e:  # url로 요청 중 오류가 발생시 실행
        print(e)
        print("Error for URL : %s" %url)
        return None
 

def main():
    sNode = 'news'  # 'news', 'blog', 'cafearticle'
    search_text = input(">검색할 키워드를 입력하세요. : ")

    targetURL = makeURL(sNode, search_text )    #1. URL 만들기
    result = requestURL(targetURL)              #2. URL로 크롤링
    print(result)                               #3. 크롤링 결과 출력


main()
# Out:
# >검색할 키워드를 입력하세요. :  일본
# Url Request Success
# {
# "lastBuildDate": "Wed, 07 Aug 2019 15:02:49 +0900",
# "total": 8440710,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "포항제철 창립멤버 장경환 前 포스코경영연구소 회장 별세",
# "originallink": "http://www.ajunews.com/view/20190807145626561",
# "link": "http://www.ajunews.com/view/20190807145626561",
# "description": "1983년에는 포항제철 도쿄사무소장으로 주재하면서 박태준 회장으로부터 광양제철소 건설에 <b>일본</b>... 삼성그룹 <b>일본</b> 총괄 사장을 맡기도 했다. 이후 1991년 몸담았던 포항제철로 다시 돌아와 사장 대우와 회장 특별... ",
# "pubDate": "Wed, 07 Aug 2019 15:00:00 +0900"
#
# },
# {
# "title": "'아베를 따르는 <b>일본</b>인' 현수막까지…'노 재팬' 너무 나갔나",
# "originallink": "http://news.mt.co.kr/mtview.php?no=2019080615242864936",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=008&aid=0004260364",
# "description": "[<b>일본</b>제 사무용품 '봉인', <b>일본</b> 거래 전면 '중단'…시민들 &quot;불매운동은 우리가&quot;] <b>일본</b>의 경제 보복에 대응하는 '노 재팬' 움직임이 전방위로 확산되는 가운데 일각에서 너무 나갔다는 지적도 나온다. '불매운동'의 대상과... ",
# "pubDate": "Wed, 07 Aug 2019 14:59:00 +0900"
#
# },
# {
# "title": "이해찬, 삼성 이재용 꼽으며 “기업도 과도한 日 의존 반성”",
# "originallink": "http://www.edaily.co.kr/news/newspath.asp?newsid=03293126622585024",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=018&aid=0004440408",
# "description": "이해찬 더불어민주당 대표가 최재성 <b>일본</b>특위 위원장과 함께 7일 오후 국회 의원회관에서 열린 강제징용... 안일하게 <b>일본</b>에 의존해온 걸 반성하고 기술 자립을 하기 위해 마음을 단단히 먹었다더라”라며 “<b>일본</b>이라는... ",
# "pubDate": "Wed, 07 Aug 2019 14:59:00 +0900"
#
# },
# {
# "title": "美 싱크탱크 CSIS “수출규제 조치, 日 이익에 손상 끼칠 수 있어”",
# "originallink": "http://www.segye.com/content/html/2019/08/07/20190807506614.html?OutUrl=naver",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=104&oid=022&aid=0003387264",
# "description": "<b>일본</b> 정부가 한국을 백색국가 대상에서 제외하는 법안을 공포한 가운데 이번 조치에 대해 일정한 성찰을 해야하고 <b>일본</b>의 전반적인 이익을 증가시키는지도 검토해봐야 한다는 지적이 6일(현지시간) 미 조야에서 제기됐다.... ",
# "pubDate": "Wed, 07 Aug 2019 14:59:00 +0900"
#
# },
# {
# "title": "&quot;<b>일본</b> 안 갈래요&quot;…강원교육청 대일교류 취소",
# "originallink": "http://www.youthdaily.co.kr/news/article.html?no=14984",
# "link": "http://www.youthdaily.co.kr/news/article.html?no=14984",
# "description": "최근 <b>일본</b> 정부가 한국을 백색국가(화이트리스트)에서 제외하는 경제보복을 단행하면서 <b>일본</b>제품 불매 운동이 확산하는 가운데 강원도교육청도 이에 동참하고 나섰다. 도교육청은 다음 주로 예정된 오사카 국제과학축전... ",
# "pubDate": "Wed, 07 Aug 2019 14:59:00 +0900"
#
# },
# {
# "title": "'아베 나빠' [경향포토]",
# "originallink": "http://news.khan.co.kr/kh_news/khan_art_view.html?artid=201908071458001&code=940100",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=032&aid=0002955915",
# "description": "서울 종로구 옛 <b>일본</b>대사관 앞에서 7일 열린 제1399차 <b>일본</b>군 성노예제 문제해결을 위한 정기 수요시위에서 한 어린이가 직접 만든 손팻말을 들고 있다.",
# "pubDate": "Wed, 07 Aug 2019 14:58:00 +0900"
#
# },
# {
# "title": "소, 한우, 제주 흑우",
# "originallink": "http://www.jejudomin.co.kr/news/articleView.html?idxno=114752",
# "link": "http://www.jejudomin.co.kr/news/articleView.html?idxno=114752",
# "description": "누렁소와는 다른 검은 소, 검정쉐, 또는 돌연변이, 평소 쇠고기를 좋아하던 사람이라면 <b>일본</b>의 '와규' 정도를 떠올릴 것이다. 이렇듯 '흑우'라고 하면 희귀함, 독특함의 이미지를 먼저 떠올리게 된다. 이에 반해 '한우'라고... ",
# "pubDate": "Wed, 07 Aug 2019 14:58:00 +0900"
#
# },
# {
# "title": "아베 보좌관 &quot;한국, 과거 매춘관광국&quot; 막말 논란",
# "originallink": "http://news.tf.co.kr/read/ptoday/1760043.htm",
# "link": "http://news.tf.co.kr/read/ptoday/1760043.htm",
# "description": "韓 의원들 면전서 &quot;위안부·강제징용 불법 없었다&quot; 아베 신조(安倍晋三) <b>일본</b> 총리의 최측근으로 알려진 에토 세이이치(衛藤晟一) 보좌관이 우리나라 여야 국회의원들을 만난 자리에서 &quot;과거 <b>일본</b>인들이 주로 매춘 관광으로... ",
# "pubDate": "Wed, 07 Aug 2019 14:58:00 +0900"
#
# },
# {
# "title": "日, 화이트리스트서 韓 제외 결정…양국 무역 '삐그덕'",
# "originallink": "http://www.m-i.kr/news/articleView.html?idxno=628159",
# "link": "http://www.m-i.kr/news/articleView.html?idxno=628159",
# "description": "<b>일본</b> 경제산업성은 7일 오전 한국을 화이트리스트 명단에서 제외하는 내용의 수출무역관리령 개정안을 공포했다. <b>일본</b> 정부는 지난 2일 각의(국무회의)에서 통과한 이 개정안을 이날 관보 게재를 기준으로 21일 후부터... ",
# "pubDate": "Wed, 07 Aug 2019 14:58:00 +0900"
#
# },
# {
# "title": "'<b>일본</b> 여행 보이콧'에 눈물짓는 '모두투어', 2분기 적자전환에 주가 급락...가...",
# "originallink": "http://www.newsworker.co.kr/news/articleView.html?idxno=35812",
# "link": "http://www.newsworker.co.kr/news/articleView.html?idxno=35812",
# "description": "더욱이 최근 한일관계 악화로 인한 '<b>일본</b>여행 보이콧'이 장기화됨에 따라 모두투어의 실적은 회복될 모습을... <b>일본</b> 수출 규제 사태로 인해 <b>일본</b> 여행 보이콧이 장기화 될 것이며 적어도 올해 3분기 까지는 <b>일본</b> 여행에... ",
# "pubDate": "Wed, 07 Aug 2019 14:58:00 +0900"
#
# }
# ]
# }
