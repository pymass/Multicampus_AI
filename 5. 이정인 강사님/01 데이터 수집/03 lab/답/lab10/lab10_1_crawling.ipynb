# %%
import urllib.request
import config


def makeURL(sNode, search_text ):
    base = "https://openapi.naver.com/v1/search"
    node = "/%s.json" % sNode
    parameters = "?query=%s" % urllib.parse.quote(search_text)+"&display=100"
    url = base + node + parameters
    return url


def requestURL(url):  # 매개인자로 url(http://www.naver.com.... ) 이 오면   open api 키를 header에 추가한 후, 크롤링
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", config.client_id)  # open api 키를 header에 추가
    req.add_header("X-Naver-Client-Secret", config.client_secret)  # open api 키를 header에 추가
    try:
        response = urllib.request.urlopen(req)  # 크롤링
        if response.status == 200:  # 200이면 정상 응답
            print("Url Request Success")
            data = response.read().decode('utf-8')
            return data  # 크롤링 결과 반환
    except Exception as e:  # url로 요청 중 오류가 발생시 실행
        print(e)
        print("Error for URL : %s" %url)
        return None



import json

def main():
    print("네이버 검색 프로그램입니다.")
    search_text = input(">검색할 키워드를 입력하세요.")
    #search_text = '탄핵'

    answer = input (">검색 카테고리를 선택하세요 \n 1. 네이버 뉴스, 2. 네이버 블로그 3. 네이버 카페")
    sNode = 'news'
    if answer=='1' :
        sNode = 'news'  # 'news', 'blog', 'cafearticle'
    elif answer=='2' :
        sNode = 'blog'
    elif answer=='3' :
        sNode = 'cafearticle'
    print("*******",answer)
    targetURL = makeURL(sNode, search_text )    #1. URL 만들기
    result = requestURL(targetURL)              #2. URL로 크롤링
    #print(result)                              #3. 크롤링 결과 출력


#     #4. 크롤링 전체 결과를 파일에 저장
#     filename = '%s_naver_%s_all.json' % (search_text, sNode) 

#     with open(filename, 'w', encoding='utf8') as outfile:
#         outfile.write(result)
#     print(filename +' 저장 완료' )


    #5. 크롤링 결과 중 일부만 파싱할 때
    jsonResult = []
    if result != None:
        jsonSearch = json.loads (result)    # JSON 문자열을  파이썬 딕셔너리로 load

        for post in jsonSearch["items"]  :  # items에 있는 데이터만
            title = post['title'] 
            description = post['description']
            jsonResult.append({'title': title,
                               'description': description  
                              })

    retJson = json.dumps(jsonResult,   #파이썬 딕셔너리를 json 문자열로
                         indent=4,     #들여쓰기 함
                         ensure_ascii=False) #한글 인코딩
    print(retJson)


    # 5. 파싱 결과 일부만 파일에 저장
    filename = '%s_naver_%s.json' % (search_text, sNode)

    with open(filename, 'w', encoding='utf8') as outfile:
         outfile.write(retJson)
    print(filename + ' 저장 완료')

main()
# Out:
# 네이버 검색 프로그램입니다.
# >검색할 키워드를 입력하세요. 일본
# >검색 카테고리를 선택하세요
#  1. 네이버 뉴스, 2. 네이버 블로그 3. 네이버 카페 1
# ******* 1
# Url Request Success
# 일본_naver_news_all.json 저장 완료
# [
#     {
#         "title": "경북 물기업, 베트남 물산업 진출 괄목할만한 성과",
#         "description": "또한, 밸브를 전문적으로 생산하는 에이지 밸브(주)는 현지 밸브 전문 수입업체로부터 <b>일본</b>산, 유럽산 밸브를 대체 할 제품으로 호의적인 반응을 보인 가운데 견적 요청 및 한국 현지 공장방문 문의를 하는 등 320만불의... "
#     },
#     {
#         "title": "코스피, 6거래일째 하락 1900선 후퇴-3년6개월만 최저치…깨끗한나라우 애국테...",
#         "description": "국면에 '애국테마주'로 급부상하면서 상한가를 기록했다. 이월드도 <b>일본</b> 제품 불매운동 영향으로 가격 제한폭까지 올랐다. 한편 이날 서울외환시장에서 원ㆍ달러 환율은 0.4원 내린 1214.9원에 거래를 마쳤다."
#     },
#     {
#         "title": "<b>일본</b>차 수입·판매하는 'GS·LS·효성'…렉서스 등 성장에 기여",
#         "description": "[토요타·렉서스 등 <b>일본</b>차 불매운동으로 타격입을 수도…SK·두산은 2010년대 초반 사업접어] <b>일본</b> 자동차 판매에 일부 한국 대기업들이 주역으로 앞장서고 있는 것으로 나타났다. 그간에도 대기업이 손쉬운 중소... "
#     },
#     {
#         "title": "인천시 &quot;<b>일본</b>과 행정교류 중단&quot;…민간 교류는 국민정서 고려 권고",
#         "description": "인천시가 <b>일본</b>과의 행정교류 사업을 당분간 중단하기로 했다. <b>일본</b> 정부가 7일 '화이트리스트(수출 절차 간소화 우대국)'에서 한국을 제외하는 내용의 법령 개정안을 공포한 데 따른 지방정부 차원에서의 대응이다.... "
#     },
#     {
#         "title": "“극일에 자신감 가져달라”…문 대통령, 부품업체 방문해 격려",
#         "description": "문재인 대통령은 7일 오후 <b>일본</b>이 ‘경제보복’을 감행한 이후 처음으로 기업을 방문해 격려했다. 앞서 정부는 <b>일본</b>의 수출규제에 대응하기 위해 국산 부품·소재·장비 분야를 집중적을 육성하겠다고 밝힌 바 있다. 문... "
#     },
#     {
#         "title": "김서준 해시드 대표 “미중⋅한일 분쟁은 중앙의 비효율 탓&quot;",
#         "description": "여시재 주최 블록체인 토론회, 김 대표 &quot;블록체인 같은 중립 네트워크 필요&quot; 신현성 테라 대표 &quot;암호화폐 기존 금융권과 협업 완벽 차단 규제 풀어야&quot; &quot;최근 벌어진 미국과 중국의 무역 분쟁, 한국과 <b>일본</b>의 분쟁도 중앙화된... "
#     },
#     {
#         "title": "민병두 정무위원장 &quot;코인 거래사이트 인가제, 당장은 시기상조&quot;",
#         "description": "현재 <b>일본</b>의 경우 정부가 코인 거래업을 직접 관리하고 거래사이트에 라이선스를 부과하는 방식으로 산업을 인정하고 있지만 우리나라는 코인에 대한 법적기준이 없는데다 거래업 뿐만 아니라 관련산업 전체를 규정하지... "
#     },
#     {
#         "title": "고레에다도, 정성일도 좋아한 영화 “나는 예수님이 싫다”",
#         "description": "<b>일본</b> 문화에서는 타인을 향한 지지 발언이 우리나라처럼 쉽지 않기 때문”이라며 신예 오쿠야마 히로시를 향한 거장 감독들의 이례적인 극찬을 소개해 토크 참여 관객들의 기대감을 높였다. 이어서 오쿠야마 히로시... "
#     },
#     {
#         "title": "‘셀코리아’ 언제 멈출까…외국인 엿새째 팔자 행진",
#         "description": "여기에 <b>일본</b>은 한국을 수출관리 상의 일반포괄허가 대상인 그룹 A(종전 백색국가)에서 제외하는 내용의 수출무역관리령 개정안을 공포하는 등 수출 규제를 강화했다. 이처럼 시장을 둘러싼 불확실성이 증폭되면서 원... "
#     },
#     {
#         "title": "SK엔카닷컴, <b>일본</b>차 매물은 늘고 문의는 줄어… '혼다' 브랜드 관심도 가장 많...",
#         "description": "<b>일본</b> 브랜드 차량의 등록 대수, 문의 건수, 조회수를 조사한 결과 전월 대비 매물은 늘고 문의 건수와 조회수는 줄어든 것으로 나타났다고 밝혔다. SK엔카닷컴에 등록된 닛산, 토요타, 렉서스, 인피니티, 혼다 5개 <b>일본</b>... "
#     },
#     {
#         "title": "8호태풍 프란시스코 소멸 후 9호 태풍 레끼마, 10호 크로사 위치예상경로.. 기...",
#         "description": "제10호 크로사는 괌 북북서쪽 부근해상을 이동중이며 11일 <b>일본</b> 오사카 남남동쪽 부근해상을 이동할 것으로 예상된다. 그러나 진로가 유동적일 수 있어 추후 발표되는 기상정보에 유의가 필요하다. 수요일인 오늘... "
#     },
#     {
#         "title": "민주당 ‘한국-유승민 통합 주장’에 견제구 “총선에만 눈 멀어”",
#         "description": "지금은 <b>일본</b>의 경제침략에 대응하기 위해 모든 국가적 역량을 모아야 할 때다. 정치권에서부터 솔선수범하여 <b>일본</b>의 경제침략에 효율적으로 대응하고, 국민여론이 한마음 한 뜻으로 결집될 수 있도록 최선을 다해야만... "
#     },
#     {
#         "title": "금단비가 서울 잠실직영점 오픈...벌써 피부관리 핫플레이스 명성",
#         "description": "금단비가 관계자는 &quot;현재 베트남은 <b>일본</b>과 유럽식 마사지가 뒤섞인 국적불명의 에스테틱이 판치고 있다&quot;며 &quot;앞으로 한국식 스타일을 정립해 에스테틱 시장 선두 주자로 치고 나가겠다&quot;고 강조했다."
#     },
#     {
#         "title": "창원시 내년 정부추경예산 572억 확보",
#         "description": "허성무 시장은 &quot;<b>일본</b>발 경제위기를 극복하기 위한 소재·부품 분야 혁신사업 국비 확보가 남아 있다. 창원시 소재·부품산업 경쟁력이 <b>일본</b>을 넘어서도록 하겠다&quot;고 말했다. 허 시장은 지난 6일 간부회의에서 &quot;<b>일본</b>... "
#     },
#     {
#         "title": "수원시의회, '<b>일본</b> 경제침략 규탄 수원시민행동 전체회의' 참석",
#         "description": "경기 수원시의회가 7일 의회 세미나실에서 열린 ‘<b>일본</b> 경제침략 규탄 수원시민행동 전체회의’에 참석했다.... 취지문에서는 “<b>일본</b>이 반도체 산업의 핵심재료인 소재산업의 수출 규제조치에 이어 화이트리스트에서도... "
#     },
#     {
#         "title": "농튜버(農tuber)로 이땅의 식량주권 사수를",
#         "description": "<b>일본</b>의 경제보복(화이트리스트 배제 등)으로 경고등이 켜진 가운데 약 77%에 달하는 수입 의존율을 보이는... 한국과 곡물 수급 환경이 비슷한 <b>일본</b>은 10년 전까지만 해도 곡물 자급률이 22.4%로 한국(25.3%)보다 오히려 더... "
#     },
#     {
#         "title": "[해외여행지 추천] 방콕·푸켓·치앙마이 태국 자유여행 어디로 갈까?...태국...",
#         "description": "<b>일본</b>에 실망한 사람들 중 태국을 눈여겨보는 여행객들이 많다. 태국의 가장 인기가 많은 여행지는 방콕과 치앙마이 그리고 푸켓이다. 치앙마이는 태국의 위쪽에 위치해 있다. 미얀마와 라오스 인근이며 태국 고유의... "
#     },
#     {
#         "title": "인터파크, 2분기 영업익 26억... 전년 동기比 273% ↑",
#         "description": "인터파크 관계자는 “현재 진행 중인 <b>일본</b> 이슈에서 상품과 지역을 다양하게 변화시키면서 영향을 최소화할 계획이며, 하반기는 여행과 공연 시장의 성수기이기 때문에 매출 기여도가 높은 ENT와 투어 사업의 혜택이... "
#     },
#     {
#         "title": "광주기독병원, 아시아 5개국 의과대학생 탐방 프로그램 운영",
#         "description": "광주기독병원을 탐방한 5개국 의료인 및 의과대학생 11명(한국, 대만, 홍콩, 인도, <b>일본</b>)은 1일 오전 8시부터... 한편 ICMDA 동아시아 지부 정기 컨퍼런스는 회원국(한국, <b>일본</b>, 대만, 홍콩, 중국, 몽골) 의료인들이 매년... "
#     },
#     {
#         "title": "로켓펀치 간담회서 韓日 갈등 질문 나오자…MC “답변 어려워”",
#         "description": "<b>일본</b>인 멤버가 포함된 그룹 로켓펀치의 데뷔 기념 간담회에서 한일 갈등과 관련한 질문이 나오자, 간담회 진행을 맡은 MC가 “답변이 어렵다”며 대답을 차단했다. 이 그룹 멤버 타카하시 쥬리는 <b>일본</b> 그룹 AKB48... "
#     },
#     {
#         "title": "&quot;남해 수산물도 좋아요~&quot;…남해군, 전국 이마트서 참돔·우럭 소비촉진",
#         "description": "장충남 남해군수는 &quot;남해에서 제일 많이 양식하고 있는 참돔·우럭 등이 최근 <b>일본</b>에서 수입되는 수산물로 인해 소비가 급감해 양식어가들이 곤경에 처해 있다&quot;며 &quot;이러한 어려움을 극복하기 위해 수산물 소비촉진을... "
#     },
#     {
#         "title": "나경원의 ‘우리 <b>일본</b>’ 발언이 논란이 되고 있다 (영상)",
#         "description": "나경원 자유한국당 원내대표가 <b>일본</b>을 ”우리 <b>일본</b>”이라고 불러 논란이 되고 있다.나경원 대표는 지난 6일 국회에서 열린 운영위원회 전체회의에서 ”우리 <b>일본</b>이 7월에 이야기한 다음 약 1달 동안 청와대는 추경을... "
#     },
#     {
#         "title": "강상중 도쿄대 명예교수 &quot;지소미아, 미국 개입 지렛대...파기하면 한미관계 어...",
#         "description": "되고 <b>일본</b>에 있어서 유리한 결말은 아닐 것”이라고 내다봤다. 강 명예교수는 ‘<b>일본</b>의 백색국가(화이트리스트) 제외 시행 전까지 정부 간 대화 노력이 필요하다’는 질의에 대해서는 “타협하는 타이밍이 중요하다”며... "
#     },
#     {
#         "title": "포천시, '<b>일본</b> 반도체 수출규제 피해신고센터' 운영",
#         "description": "포천시, '<b>일본</b> 반도체 수출규제 피해신고센터' 운영 경기 포천시는 <b>일본</b> 정부의 반도체 수출 규제 결정에 따른 피해기업을 신속하게 파악하고 지원하기 위해 ‘<b>일본</b> 반도체 수출규제 피해신고센터’를 운영한다고 7일... "
#     },
#     {
#         "title": "동두천시, 日 우호도시와 국제교류 일정 취소",
#         "description": "동두천시, 日 우호도시와 국제교류 일정 취소 <b>일본</b>의 일방적이고 임의적인 경제보복에 따른 범시민적 불매운동 및 규탄이 확산되고 있는 가운데 경기 동두천시가 <b>일본</b> 우호도시와의 국제교류 일정을 취소하기로 했다.... "
#     },
#     {
#         "title": "[포토Q] 로켓펀치 '빔밤붐' 공개하는 데뷔 쇼케이스",
#         "description": "특히 AKB48로 <b>일본</b>에서 활동한 다카하시 쥬리는 Mnet '프로듀스48' 이후 한국에 정식 데뷔하며 팬들의 관심을 모았다. 미니앨범 1집 '핑크펀치'의 수록곡 6곡 중 '빔밤붐(BIM BAM BUM)'이 타이틀곡으로 선정됐다.... "
#     },
#     {
#         "title": "군수품 국산화개발 지원 확대, 군수품 생산기업 제조혁신 지원",
#         "description": "협약식에서 박영선 중기부장관은 “최근 <b>일본</b>의 수출규제 상황에서 군수품 국산화개발 지원 확대 협력은 시의적절한 대응이다. 이를 통해 해외 의존도가 높은 군수품의 국산화율과 중소기업 경쟁력도 함께 높아질 것”... "
#     },
#     {
#         "title": "[뉴스워커_국제정세] 미․중 환율전쟁 진정세, 태풍급 악재로 둘러싸인 한국 ...",
#         "description": "<b>일본</b>의 수출규제로 경제적 어려움에 직면해 있는 상황에서 미-중 무역전쟁의 확전이라는 악재가 등장해 우리... 이렇게 현재 한국 경제는 <b>일본</b>의 수출 규제와 미중 무역전쟁의 확전 양상, 환율 불안정 등 태풍급 악재에... "
#     },
#     {
#         "title": "[종합] ‘로켓펀치’의 귀여운 한방 ‘빔밤붐’ ...“멤버 모두 센터 가능”",
#         "description": "멤버들은 <b>일본</b>인 멤버 쥬리를 위해 <b>일본</b>어 공부에 매진하고, 쥬리는 한국어 공부에 매진했다는 후문. 쥬리는 ‘답답하’는 의미를 지닌 ‘고구마’란 한국어 단어가 좋다고 말해 웃음을 자아냈다. 연희는... "
#     },
#     {
#         "title": "홍남기 &quot;증시수급 안정책, 공매도 규제 등 총동원“",
#         "description": "악화, <b>일본</b>의 수출 규제 등이 어려움을 더하고 있다&quot;고 설명했다. 그러면서 &quot;정부는 앞으로 상황을 냉철하게... 홍 부총리는 <b>일본</b>의 수출 규제 조치에 대해서는 &quot;<b>일본</b> 측에 이번 부당한 조치의 조속한 철회를 강력히... "
#     },
#     {
#         "title": "에스퍼 美 국방 “美 미사일 배치, 누구에게도 요청한적 없어”",
#         "description": "아시아·태평양 순방 일정을 소화 중인 에스퍼 장관은 이날 호주를 떠나 <b>일본</b> 방문길에 오르는 자리에서... 이후 한국과 <b>일본</b> 등이 배치 후보지역으로 거론됐고, 우리 청와대는 미 정부가 거론하고 있는 미 중거리 미사일의... "
#     },
#     {
#         "title": "'봉오동 전투' 전체 예매율 1위 등극…흥행 다크호스 급부상",
#         "description": "1920년 6월, 죽음의 골짜기로 <b>일본</b> 정규군을 유인해 최초의 승리를 이룬 독립군들의 전투를 그린 영화 '봉오동 전투' 가 영화진흥위원회 영화관 입장권 통합전산망 기준 전체 예매율 1위에 오르며 흥행 청신호를... "
#     },
#     {
#         "title": "日 방위상 &quot;6일 北 발사체, 단거리 탄도미사일…안보리 결의 위반&quot;",
#         "description": "이와야 다케시(岩屋毅) <b>일본</b> 방위상은 북한이 지난 6일 발사한 발사체(2발)와 관련 &quot;분석 결과 '단거리... 보도에 따르면 <b>일본</b> 방위성은 북한이 군사 기술을 향상시키고 있으며, 동시에 한국·미국·<b>일본</b>을 견제하려는... "
#     },
#     {
#         "title": "日언론 &quot;한국 스포츠, <b>일본</b> 배제 격화…교류 위축&quot;",
#         "description": "<b>일본</b> 언론에서 한일 갈등으로 인한 한국 스포츠계의 움직임을 자세히 다뤘다. <b>일본</b> 데일리스포츠는 7일 '한국 스포츠계 <b>일본</b> 배제 격화, 컬링 이어 농구도 초청 철회'라는 제목의 기사를 통해 최근 한국 스포츠계에서... "
#     },
#     {
#         "title": "“자문 해주겠다” <b>일본</b> 경제보복에 ‘기술 방패’로 나선 대학들",
#         "description": "절박한 중소기업, 카이스트 하루 만에 상담신청 60건 쇄도 <b>일본</b>의 경제보복에 첨단기술을 연구하는 대학들이... 카이스트는 지난 2일 <b>일본</b>이 ‘화이트리스트’(수출심사 우대국)에서 한국을 제외한다고 발표하자 비상... "
#     },
#     {
#         "title": "[아시아 증시] 미중 분쟁 고조 속 日·中하락",
#         "description": "<b>일본</b> 닛케이225종합지수는 전 거래일 대비 0.33% 하락한 2만516.56엔으로 마감했다. 토픽스(TOPIX)는 0.05% 내린 1499.93엔으로 장을 마쳤다. 닛케이지수는 엔고 영향으로 하락했다. 미중 간 갈등이 환율전쟁으로 확전된... "
#     },
#     {
#         "title": "중기부, 추경으로 1.2조원 확보... 민생경제 회복에 총력 지원",
#         "description": "[사진=연합뉴스] 중기부가 추경으로 1조2000억원의 예산을 추가 확보하게 돼, <b>일본</b> 수출규제로 불확실성이 커진 중소·벤처업계에 지원을 늘릴 수 있게 됐다. <b>일본</b> 수출 규제 대응, 미세먼지와 강원 산불 등 재난 피해에... "
#     },
#     {
#         "title": "[뉴스워커_국회] 김정우 의원, &quot;우리 정부, 전범기업 물품 10년간 9,098억원 ...",
#         "description": "최근 10년간 우리 정부가 <b>일본</b> 전범기업의 물품을 구매하는데 총 9,098억원을 사용한 것으로 나타났다. 국회... 등 <b>일본</b> 전범기업들이 생산한 것이다. 김정우 의원은 &quot;정부가 매년 평균 900억원 이상의 국민 세금을... "
#     },
#     {
#         "title": "금값 사흘째 최고가 경신…안전자산 선호 영향",
#         "description": "국내 금 가격은 <b>일본</b>이 우리나라를 백색국가에서 제외키로 결정한 지난 2일부터 사흘 연속 최고가를 경신 중이다. 이 같은 금 값 상승세는 최근 미중 무역분쟁 격화 및 <b>일본</b>의 수출 규제 등의 영향으로 대내외... "
#     },
#     {
#         "title": "[지자체의 SR] 동두천시, <b>일본</b> 우호도시 시마다시와 국제교류 일정 취소",
#         "description": "ⓒ동두천시 [SR(에스알)타임스 최정규 기자] 경기 동두천시(시장 최용덕)는 <b>일본</b> 우호도시인 시마다시와 금년 10월중 진행 예정이었던 국제교류 일정을 취소했다고 밝혔다. 앞서 동두천시는 2011년 <b>일본</b> 시즈오카현... "
#     },
#     {
#         "title": "(전주시청-종합) 전주시 방역소독, 모기 '꼼짝마!'",
#         "description": "전주시보건소는 여름철을 맞아 개체수가 증가하고 있는 모기에 의한 감염병인 <b>일본</b>뇌염과 뎅기열, 말라리아, 지카바리어스 등을 예방하기 위한 방역소독을 실시한다고 6일 밝혔다. 보건소는 이를 위해 △방역기동반 5명... "
#     },
#     {
#         "title": "'독일인 명예의 전당' 만든 나노",
#         "description": "나노가 최근 주목받는 것은 ‘기술독립’을 통해 국내 시장을 독점해온 <b>일본</b>산 탈질필터를 90% 이상 대체해서다. 신동우 나노 회장은 “현재 국내 화력발전소의 <b>일본</b> 탈질촉매 공급은 10% 미만에 그치고 있다”며 “선박... "
#     },
#     {
#         "title": "금융수장 모두 모여 “시장안정 수단 총동원할 것”",
#         "description": "<b>일본</b> 수출 규제에다 국내 기업실적 악화 등이 어려움을 더하고 있다고 설명했습니다. 정부는 다만, 외화보유액과 순대외채권이 4천억 달러를 넘은 만큼 과도한 불안 심리를 가질 필요는 없다고 강조했습니다. KBS 뉴스... "
#     },
#     {
#         "title": "日, ‘한국 백색국가 제외’ 공포…“핵, 군사용 전용 우려 물품 개별허가”",
#         "description": "<b>일본</b> 정부가 오늘 한국을 이른바 '백색국가'에서 제외하는 내용의 시행령 개정안을 공포했습니다. 일단... [리포트] <b>일본</b> 정부가 오늘 관보 게재를 통해 한국을 백색국가에서 제외하는 법령 개정안을 공포했습니다.... "
#     },
#     {
#         "title": "에스퍼 미 국방 “중국, 군사ㆍ경제적으로 국제규칙 위협”",
#         "description": "아시아 순방의 일환으로 7일 취임 후 처음 <b>일본</b>을 찾은 마크 에스퍼 미국 국방장관이 아베 신조(安倍晋三) <b>일본</b> 총리 등 <b>일본</b> 정부 핵심 인사들을 만나 의견을 교환하면서 중국에 대한 견제 의지를 노골적으로 드러냈다. 1년... "
#     },
#     {
#         "title": "‘<b>일본</b>차 거부’, 중고차 시장에서 뚜렷…SK엔카닷컴, “매물 늘고 관심 줄어...",
#         "description": "SK엔카 직영 중고차 플랫폼 SK엔카닷컴은 7월 한 달간 SK엔카닷컴에 등록된 5개 <b>일본</b> 브랜드 차량의 등록... SK엔카닷컴에 등록된 닛산, 토요타, 렉서스, 인피니티, 혼다 5개 <b>일본</b> 브랜드 차량의 관심도는 일제히... "
#     },
#     {
#         "title": "전북은행, <b>일본</b> 수출규제 피해기업 금융지원 나선다",
#         "description": "전북은행 본점 (사진제공 = JB금융지주) JB금융그룹 전북은행(은행장 임용택)은 <b>일본</b>의 수출규제 조치로... 이번 <b>일본</b>수출규제와 관련해 전라북도의 조사결과, 도내 주력산업 관련 기업체 1,344개 중 약 3.5%에 해당하는... "
#     },
#     {
#         "title": "경남도, <b>일본</b> 수출규제 관련 긴급경영안정자금 300억원 지원",
#         "description": "경남도(도지사 김경수)가 최근 <b>일본</b> 수출규제 조치에 따른 도내 중소기업의 안정적인 경영 지원을 위해 긴급 경영안정자금 300억원을 투입한다. 이번에 지원하는 긴급자금은 지난 7월 1일 이후 <b>일본</b>의 수출규제... "
#     },
#     {
#         "title": "선사 시대 동굴 벽화서 전쟁의 흔적을 찾다",
#         "description": "전쟁의 기원 아더 훼릴 지음/ 이춘근 옮김/ 북앤피플 펴냄 전쟁은 인간이 만든 사회제도 구석기 시대로 연원 추적 나서 심리·인류학 등 전쟁 이론 소개도 최근 <b>일본</b>이 한국을 ‘화이트리스트’에서 배제한 것을 계기로... "
#     },
#     {
#         "title": "<b>일본</b>행 항공권 직원 구매 급증 의혹···대한항공 &quot;사실무근, 오히려 줄었다...",
#         "description": "대한항공(003490)이 최근 <b>일본</b>행 항공권의 직원 구매가 급증하고 있다는의혹 제기에 사실이 아니라고 해명했다. 대한항공은 7일 입장문을 내고 직원 항공권 제도를 이용해 <b>일본</b>행 항공편 탑승한 직원들이 늘어났다는... "
#     },
#     {
#         "title": "나경원 &quot;文정권, 9·19 군사합의 붙들다 동네북 신세 만들어&quot;",
#         "description": "군사정보보호협정)를 <b>일본</b>의 대 한국 수출규제조치에 대항해 파기해야 한다는 주장이 정부로부터 나오고... 그는 &quot;어제 국회 운영위원회에 출석한 노 비서실장은 정부가 강제징용 배상 판결의 후속 조치로 <b>일본</b> 측에 1+1... "
#     },
#     {
#         "title": "인터파크, 2분기 영업익 26억원…전년동기比 273%↑",
#         "description": "인터파크 관계자는 “현재 진행 중인 <b>일본</b> 이슈에 대해서는 상품 및 지역 다변화 전략을 통해 영향을 최소화할 계획”이라면서 “하반기는 여행 및 공연 시장 성수기 진입으로 매출 기여도 높은 ENT 및 투어 사업의... "
#     },
#     {
#         "title": "포천시의회, 12일 '<b>일본</b> 정부 경제 보복에 대한 규탄 결의안' 의결",
#         "description": "포천시의회, 12일 '<b>일본</b> 정부 경제 보복에 대한 규탄 결의안' 의결 경기 포천시의회는 오는 12일 ‘<b>일본</b> 정부의 경제 보복에 대한 규탄 결의안’을 의결하기 위해 긴급 임시회를 개회한다고 7일 밝혔다. 이번 임시회에서는... "
#     },
#     {
#         "title": "[뉴스워커_국회] 이원욱 의원, 정보통신산업 진흥법 개정안 발의",
#         "description": "최근 <b>일본</b>의 수출규제사태로 인해 국내 산업경쟁력이 약화될 것이라는 우려가 제기되고 있다. 그러나 이번 일을 계기로 국내 산업의 체질을 개선해 산업생태계를 새롭게 조성해야 한다는 의견도 제시되고 있다. 이를 위해... "
#     },
#     {
#         "title": "&quot;참신한 IP가 없다&quot; 투자매력 잃은 게임, VC도 외면",
#         "description": "지난해 12월 상장한 베스파와 올해 5월 상장한 <b>일본</b> 게임 회사 SNK의 주가는 모두 공모가 대비 30% 이상 하락했다. 여기에 게임 장애를 질병으로 등재하는 움직임도 투자 위축에 한몫을 하고 있다. 대형게임사들은... "
#     },
#     {
#         "title": "한국개발연구원, 5달째 “경기 부진”…“우리 경제 하방 위험 커져”",
#         "description": "낮은 수준에 머무는 등 경기 전반에 부진을 보여줬다&quot;고 평가했습니다. 김성태 KDI 경제전망실장은 &quot;미중 무역갈등과 <b>일본</b>의 수출규제 등 통상마찰이 심화하면서 우리 경제 하방 위험이 확대되고 있다&quot;고 말했습니다. KBS"
#     },
#     {
#         "title": "문 대통령 부품 국산화 성공 기업 방문…“강소기업에겐 오히려 도약 기회”",
#         "description": "<b>일본</b>이 우리나라를 수출심사 우대국에서 제외하는 시행령을 공포한 가운데, 문재인 대통령이 오늘 부품 국산화에 성공한 강소기업을 방문해 직원들을 격려했습니다. 정부는 부품 소재 산업의 국산화, 탈<b>일본</b>화를 위해... "
#     },
#     {
#         "title": "<b>일본</b>, 화이트리스트서 한국 배제…A등급→B등급 ‘강등’",
#         "description": "<b>일본</b>이 우리나라를 수출우대국, 이른바 화이트리스트에서 제외하는 개정안을 공포했습니다. 하지만 개정안... <b>일본</b> 경제산업성은 오늘(7일) 오전 우리나라를 화이트리스트에서 제외하는 내용의 시행령 개정안을 관보에... "
#     },
#     {
#         "title": "日 '한국여행주의보' 관광객 줄어드나… 서울시, 중국에 러브콜",
#         "description": "<b>일본</b>이 ‘한국여행주의보’를 내리면서 <b>일본</b>인 관광객 감소가 우려되자 서울시가 중국 관광시장을 겨냥한 대책을 내놨다. 최근 한일 관계 경색으로 피해를 본 관광업계에는 담보 없이 최대 5,000만원의 특별 금융 지원도... "
#     },
#     {
#         "title": "“아베의 준비 안 된 전쟁, 결국 日경제에 부메랑” - FP",
#         "description": " 미국 유력 외교전문 매체 포린폴리시(FP)가 6일(현지시간) ‘<b>일본</b>이 준비도 안 된 채 전쟁에 나섰다’는 제목의 사설에서 아베 신조(安倍晋三) <b>일본</b> 총리가 한국을 공격하며 내세운 근거가 빈약하고 <b>일본</b> 경제에 닥쳐올... "
#     },
#     {
#         "title": "'봉오동전투' 개봉 첫날 예매율 1위 등극!…화제성 입증하며 흥행 청신호",
#         "description": "영화 '봉오동 전투'는 1920년 6월, 죽음의 골짜기로 <b>일본</b> 정규군을 유인해 최초의 승리를 이룬 독립군들의 전투를 그린 작품. 온라인 조사 회사 피엠아이(PMI)가 '헤이폴(heypoll)'사이트를 통해 20-50대 남녀를 대상으로... "
#     },
#     {
#         "title": "문 대통령, 부품·소재·장비 국산 경쟁력 제고 강조",
#         "description": "이 업체가 생산하는 제품 중 감속기는 <b>일본</b>이 분류한 전략물자에 포함되지 않으나, 이 감속기의 핵심 부품인 베어링은 전략물자에 포함된다고 청와대는 전했다. 특히 이제까지 대부분 <b>일본</b>에서 수입해 오던 '로봇용... "
#     },
#     {
#         "title": "[카드뉴스] ‘<b>일본</b>말’인 줄 몰랐던 의외의 <b>일본</b> 단어7",
#         "description": "생활속 <b>일본</b>식 외래어를 정리해봤다. ■뗑깡 뗑깡 흔히 어떤 일이 잘 돌아갈 때 훼방을 놓거나 쓸데 없는 짓을 하여 분위기를 망치는 경우에 사용된다. 하지만 이 말은 ‘간질병’을 뜻하는 <b>일본</b>어로 일제에 대항하던 우리... "
#     },
#     {
#         "title": "더불어민주당 하남지역위원회 ‘NO JAPAN’ 거리 캠페인 나서",
#         "description": "더불어민주당 하남지역위원회 소속 시의원들은 오늘 시청 사거리에서 <b>일본</b>의 경제 보복 조치에 대한 비판과 함께 <b>일본</b>제품 불매운동을 촉구하는 거리 캠페인에 나섰습니다. 캠페인에 참석한 의원들은 <b>일본</b> 정부의... "
#     },
#     {
#         "title": "‘<b>일본</b> 우익 블랙리스트’ 영화 서울서 상영",
#         "description": "‘<b>일본</b> 우익정부의 최고 블랙리스트’ 영화감독 아다치 마사오의 영화 ‘은하계에서 온 소식’이... 그는 <b>일본</b> 현대 사회의 변화 속 실험영화라는 예술적 매개체를 통해 <b>일본</b>을 비롯한 전 세계의 부조리와 정치적... "
#     },
#     {
#         "title": "“아이치트리엔날레 전시 중단 유감”",
#         "description": "앞서 아이치트리엔날레 전시실행위원회는 3일 “<b>일본</b>의 ‘표현의 부자유’ 상황을 생각하자는 기획 의도를 주최자가 스스로 탄압하는 것은 역사적 폭거”라며 “전후 <b>일본</b> 최대 검열사건이 될 것“이라고 밝혔다. 한편... "
#     },
#     {
#         "title": "트럼프 &quot;경제성장 이룬 국가들이 개도국 특혜 누려&quot;",
#         "description": "핵심 타깃은 중국…&quot;한국 농업 영향 없을 듯&quot; <b>일본</b>이 한국에 대한 수출 규제 공세를 취하고 있는 가운데, 도널드 트럼프 미국 대통령이 한국의 ‘개발도상국’ 지위를 문제 삼아 우리 통상 분야에 또다른 위협이... "
#     },
#     {
#         "title": "편의점 CU, <b>일본</b> 색 빼기 가장 적극적",
#         "description": "맥주 이어 1+1, 2+1등 할인행사서 日제품 제외 편의점업계가 <b>일본</b>산 맥주를 사실상 ‘퇴출’시킨데 이어 음료, 생활용품 등도 할인 행사에서 배제하는 등 ‘<b>일본</b>색’ 빼기에 한창이다. 편의점 CU가 ‘불매 운동’에 가장... "
#     },
#     {
#         "title": "日·美·中 악재에 내년 성장률도 장담 못한다… 전문가들 “2%대 초반” 전망",
#         "description": "<b>일본</b> 수출규제가 급부상했고, 미·중 무역갈등은 변수로 등장했다. KDI는 “미·중 무역갈등, <b>일본</b> 수출규제 등 통상 마찰이 심화하면서 우리 경제의 하방 위험이 확대되고 있다”고 설명했다. 이런 움직임은 정부의... "
#     },
#     {
#         "title": "강상중 도쿄대 교수 “지소미아 파기, <b>일본</b>에 불리한 결말…한ㆍ미 관계도 어...",
#         "description": "지소미아 파기로 <b>일본</b>에 본때를 보여줘야 한다는 주장과 지소미아 파기 시 한·미 동맹의 위기가 온다는... 강 교수는 한·일 대치 상황에서 지소미아 연장 여부를 <b>일본</b>을 압박한 카드로 쓸 여지는 있다고 봤다. 그는... "
#     },
#     {
#         "title": "日 돗토리현, 韓 관광객 급감에 '긴급융자'",
#         "description": "한일 관계 악화로 <b>일본</b>을 찾는 한국인 관광객이 급감해 피해가 커지자 <b>일본</b> 돗토리현이 긴급 융자 지원에 나섰습니다. 돗토리현 히라이 신지 지사는 지난달 31일 기자회견에서 관광객 감소로 피해를 입게 되는 관광업계... "
#     },
#     {
#         "title": "아베 측근 &quot;한국은 과거 매춘 관광국&quot;",
#         "description": "아베 신조 <b>일본</b> 총리의 측근인 에토 세이이치 자민당 참의원이 최근 <b>일본</b>을 방문한 여야 정치인들 앞에서 우리나라를 '매춘 관광국'으로 지칭하는 발언을 한 것으로 전해졌습니다. 에토 의원은 지난 1일, <b>일본</b>을 방문한 여야... "
#     },
#     {
#         "title": "[포토] 日 수출규제에 대한 과학기술계 대응방안 토론",
#         "description": "김명자 한국과학기술단체총연합회장이 7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 인사말하고 있다./ kimhyun81@"
#     },
#     {
#         "title": "[포토] 인사말하는 김명자 연합회장",
#         "description": "김명자 한국과학기술단체총연합회장이 7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 인사말하고 있다./ kimhyun81@"
#     },
#     {
#         "title": "[포토] 日 수출규제에 대한 과학기술계 대응방안 토론",
#         "description": "7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 좌장을 맡은 장석인 산업연구원 선임연구위원이 지정토론을 이끌고 있다./ kimhyun81@"
#     },
#     {
#         "title": "[포토] 日 수출규제 과학기술계 대응방안 토론회",
#         "description": "7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 좌장을 맡은 장석인 산업연구원 선임연구위원이 지정토론을 이끌고 있다./ kimhyun81@"
#     },
#     {
#         "title": "[포토] 日 수출규제에 대한 대응방안 토론회",
#         "description": "7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 좌장을 맡은 장석인 산업연구원 선임연구위원이 지정토론을 이끌고 있다./ kimhyun81@"
#     },
#     {
#         "title": "[포토] 日수출규제 대응방안 모색하는 과학기술계",
#         "description": "7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 좌장을 맡은 장석인 산업연구원 선임연구위원이 지정토론을 이끌고 있다./ kimhyun81@"
#     },
#     {
#         "title": "[포토] 과학기술계, 日수출규제 대응방안 모색",
#         "description": "7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 좌장을 맡은 장석인 산업연구원 선임연구위원이 지정토론을 이끌고 있다./ kimhyun81@"
#     },
#     {
#         "title": "[포토] 日 수출규제 대응방안 토론회 참석 패널들",
#         "description": "7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 패널들이 자리하고 있다./ kimhyun81@"
#     },
#     {
#         "title": "[포토] 지정토론 이끄는 장석인 선임연구원",
#         "description": "7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 좌장을 맡은 장석인 산업연구원 선임연구위원이 지정토론을 이끌고 있다./ kimhyun81@"
#     },
#     {
#         "title": "올림픽 보이콧? 어린애 투정인가?",
#         "description": "심지어 민주당 소속 신동근의원은 &quot;도쿄 올림픽이 <b>일본</b>의 약한 고리&quot;라며 &quot;아베 총리에게 정치적으로 큰 타격을 입힐 수 있다&quot;고 발언했다. 자유한국당은 7일 &quot;올림픽은 국제사회에서 전쟁과 분쟁을 없애기 위한 도구로... "
#     },
#     {
#         "title": "일, 한국을 '그룹 A'에서 공식 제외... 28일부터 '그룹 B' 적용",
#         "description": "<b>일본</b>이 7일 관보를 통해 한국을 '그룹 A(화이트리스트_백색국가)'에서 제외한다고 공식 발표했다. 이날 <b>일본</b> 정부가 공포한 수출무역관리령 개정안은 공포 후 21일이 경과한 날로부터 시행하도록 돼 있어 한국은 오는... "
#     },
#     {
#         "title": "<b>일본</b>, '한국 백색국가 제외' 공포…28일부터 시행",
#         "description": "【 앵커멘트 】 <b>일본</b> 정부가 예고대로 우리나라를 수출 우대국, 백색국가에서 제외하는 법령 개정안을... 【 기자 】 <b>일본</b> 정부가 관보에 게재한 내용입니다. 수출무역관리령의 일부를 개정해 대한민국을 삭제한다고 적혀... "
#     },
#     {
#         "title": "文 대통령, 부품업체 방문 &quot;日수출규제, 도약 기회 될 수도&quot;",
#         "description": "이번 방문은 <b>일본</b>의 경제보복 사태 후 첫 현장방문으로, 정부는 앞서 <b>일본</b>의 수출규제에 대비해 국산 부품ㆍ소재ㆍ장비 분야를 집중 육성하겠다고 밝혔다. 문 대통령이 이날 방문한 SBB테크는 반도체ㆍLCD 장비 및 로봇... "
#     },
#     {
#         "title": "민주당 서재헌 부대변인 &quot;아베 보좌관 에토 세이이치, 역시 '아베스러워'&quot;",
#         "description": "과거 <b>일본</b>은 한국을 매춘 관광으로 찾았는데, 나는 하기 싫어서 잘 가지 않았다&quot;, &quot;강제징용, 위안부 문제... 이에 서 부대변인은 &quot;아베 신조 <b>일본</b> 총리 보좌관인 에토 세이이치가 아베총리의 행보를 그대로 답습하고 있다.... "
#     },
#     {
#         "title": "강상중 &quot;GSOMIA 연장 불발 시, 한미관계 어려워질 것&quot;",
#         "description": "이런 경우 도널드 트럼프 미국 대통령이 중개할 여지가 생기게 되고 <b>일본</b>에 있어서 유리한 결말은 아닐 것&quot;이라고 전망했다. 김 명예교수는 <b>일본</b>의 백색국가(화이트리스트) 제외 시행 전까지 정부 간 대화 노력이 필요하다... "
#     },
#     {
#         "title": "7일 태국 바트 살때 39.9원, 팔때 39.11원 ▲0.51%상승",
#         "description": "■ 태국환율 환전예상가▲지난 2주간 태국 바트 환율변화(출처=한국수출입은행)지난 2주간 <b>일본</b> 바트는 등락을 거듭하며 평균적으로  39.02원의 가격을 보였다. 내일 환전예상가는 살때 39.25원, 팔때 38.47원이다.상기... "
#     },
#     {
#         "title": "[NC현장]쥬리, '프듀48' 잇는 도전…가요계 정조준하는 로켓펀치의 한방",
#         "description": "AKB48로서 <b>일본</b>에서 걸그룹 활동을 했던 쥬리는 K팝 걸그룹의 일원으로 다시 시작하게 됐다. 한국 활동을 택한... <b>일본</b> 그룹 활동과 한국 그룹 활동의 차이점을 묻자 쥬리는 숙소 생활을 꼽았다. 그는 &quot;처음이니까 긴장이... "
#     },
#     {
#         "title": "국제파워보트대회 10일 목포 평화광장서 개최",
#         "description": "우리나라를 비롯한 <b>일본</b>, 태국 선수들이 일명 제트스키로 불리는 수상오토바이를 타고 시원한 물살을 가르는 박진감 있는 스피드를 뽐낸다. 한여름 무더위와 일상의 스트레스를 한방에 날리는 색다른 묘미를 선사한다.... "
#     },
#     {
#         "title": "김영록 전남도지사, '日수출규제' 현장서 답 찾는다",
#         "description": "김영록 전라남도지사는 7일 전남테크노파크에서 <b>일본</b> 수출 규제로 피해 발생이 우려되는 여수, 순천, 광양... 여수, 순천, 광양 지역에 밀집해 있는 화학·금속산업의 경우 전남지역 산업 가운데 <b>일본</b> 수입액이 가장 많은... "
#     },
#     {
#         "title": "美 볼턴 “북한 미사일 시험발사 약속 위반 아냐”",
#         "description": "<b>일본</b>을 방문 중인 마크 에스퍼 미 국방장관은 6일 북한의 연이은 미사일 도발에 대해 “미국은 과도하게 반응하지 않을 것이다”면서 “북한과의 대화를 위해 문을 계속 열어둘 것이다”고 말했다. 에스퍼 장관은 이날... "
#     },
#     {
#         "title": "울산 주력산업 주요부품 이미 국산화",
#         "description": "울산이 <b>일본</b>의 수출규제에도 불구하고 여파가 미미할 것으로 분석됐다.주요 부품의 국산화가 빠르게 이뤄지면서 위기 속에 든든한 버팀목이 되고 있다. 7일 울산시에 따르면 울산의 대<b>일본</b> 수출입현황은 2018년 기준... "
#     },
#     {
#         "title": "'<b>일본</b> 여행 거부' 확산에 제주항공도 <b>일본</b> 노선 35% 감편",
#         "description": "<b>일본</b> 여행 거부 운동 확산 움직임이 커지자 제주항공도 <b>일본</b> 노선 감편 계획을 서둘러 확정했습니다. 제주항공은 <b>일본</b> 노선 운항을 35% 감축합니다. 오늘(7일) 항공업계와 제주항공에 따르면 제주항공은 다음 달... "
#     },
#     {
#         "title": "관광업계 민주당에 쓴소리…&quot;한일 민간교류까지 막는 건 자제해야&quot;",
#         "description": "이 자리에 함께 한 박양우 문화체육관광부 장관은 &quot;<b>일본</b>인 관광객의 감소가 예상되는 만큼 아시아 국가를 대상으로 하는, 맞춤형 홍보 마케팅으로 방한 관광시장의 활성화를 병행할 것&quot;이라면서 &quot;정부가 관광 업계와 힘을... "
#     },
#     {
#         "title": "[포토] 반도체-디스플레이 수출규제 대응방안 토론회",
#         "description": "박재근 한국반도체디스플레이기술학회장(한양대 교수)가 7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 주제발표를 하고 있다./ kimhyun81@"
#     },
#     {
#         "title": "[포토] 日 수출 규제에 따른 과학기술계 대응방안 토론회",
#         "description": "박재근 한국반도체디스플레이기술학회장(한양대 교수)가 7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 주제발표를 하고 있다./ kimhyun81@"
#     },
#     {
#         "title": "[포토] 발표하는 박재근 교수",
#         "description": "박재근 한국반도체디스플레이기술학회장(한양대 교수)가 7일 서울 서초구 양재 엘타워에서 열린 <b>일본</b> 반도체-디스플레이 소재 수출규제에 대한 과학기술계 대응방안 토론회에서 주제발표를 하고 있다./ kimhyun81@"
#     },
#     {
#         "title": "日대사관 앞 수요집회…&quot;NO <b>일본</b>! 전쟁범죄 사죄하라&quot;",
#         "description": "<b>일본</b> 정부가 '화이트리스트'에서 한국을 제외하는 내용의 법령 개정안을 공포한 7일을 기점으로 'NO <b>일본</b>'운동이 점차 확산되는 가운데, <b>일본</b>의 전쟁 범죄를 규탄하는 시위가 이어졌다. 정의기억연대 등은 이날 정오 서울... "
#     },
#     {
#         "title": "[김종훈 칼럼]<b>일본</b> 수출규제 3대 품목 문제의 본질은 사람이다.",
#         "description": "최근 <b>일본</b>이 수출규제를 하는 PR/불산류/불화폴리이미드 3대 품목에 집중을 해서 문제의 본질이 무엇인지... <b>일본</b>에서 EUV 감광제 안 준다고 그 위상이 흔들릴 리 있겠는가? 하지만 <b>일본</b>에서 특정 '소재'를 수출하지... "
#     }
# ]
# 일본_naver_news.json 저장 완료
