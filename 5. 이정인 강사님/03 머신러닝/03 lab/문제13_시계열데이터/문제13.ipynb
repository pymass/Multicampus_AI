# %%
import pandas as pd

sales = pd.read_csv('sales.csv', encoding='euc-kr', index_col=0)

# %%
sales
# Out:
#        1월   2월   3월   4월   5월   6월
# 2000  100  110  120  130  144  155
# 2001  150  160  177  188  199  200
# 2002  200  220  240  260  280  300
# 2003  101  112  121  131  143  154
# 2004  151  161  175  186  190  200
# 2005  150  168  170  186  190  200
# 2006  100  110  120  130  144  155
# 2007  150  160  177  188  199  200
# 2008  200  220  240  260  280  300
# 2009  101  112  121  131  143  154
# 2010  151  161  175  186  190  200
# 2011  150  168  170  186  190  200
# 2012  100  110  120  130  144  155
# 2013  150  160  177  188  199  200
# 2014  200  220  240  260  280  300
# 2015  101  112  121  131  143  154
# 2016  151  161  175  186  190  200
# 2017  150  168  170  186  190  200
# 2018  100  110  120  130  144  155
# 2019  150  160  177  188  199  200

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense


def make_model() :
    model = Sequential()
    model.add( SimpleRNN(10, input_shape=(3,1)) ) 
    model.add( Dense(1) )  #, activation="linear"
    model.compile( loss='mse' , optimizer='sgd')
    model.summary()
    return model
# Out:
# Using TensorFlow backend.

# %%
model = make_model()
# Out:
# WARNING:tensorflow:From C:\Users\Administrator\Anaconda3\envs\multicampus\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 10)                120
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 131
# Trainable params: 131
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(sales)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-cdfa18011f58> in <module>
# ----> 1 model.fit(sales)
#
# ~\Anaconda3\envs\multicampus\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# ~\Anaconda3\envs\multicampus\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# ~\Anaconda3\envs\multicampus\lib\site-packages\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     126                         ': expected ' + names[i] + ' to have ' +
#     127                         str(len(shape)) + ' dimensions, but got array '
# --> 128                         'with shape ' + str(data_shape))
#     129                 if not check_batch_axis:
#     130                     data_shape = data_shape[1:]
#
# ValueError: Error when checking input: expected simple_rnn_1_input to have 3 dimensions, but got array with shape (20, 6)
